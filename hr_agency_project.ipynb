# %% [markdown]
# # Проект "Кадровое агенство"
#
# Задачей проекта является выявление факторов, влияющих на популярность вакансий. В распоряжении датасет с вакансиями, упор необходимо сделать на вакансии, закрытые кадровым агентством.

# %% [markdown]
# [Презентация](https://disk.yandex.ru/i/1SLnQ4ODNYToXA)

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Декомпозиция" data-toc-modified-id="Декомпозиция-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Декомпозиция</a></span></li><li><span><a href="#Загрузка-библиотек-и-данных" data-toc-modified-id="Загрузка-библиотек-и-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка библиотек и данных</a></span><ul class="toc-item"><li><span><a href="#Предварительный-обзор-данных" data-toc-modified-id="Предварительный-обзор-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Предварительный обзор данных</a></span></li></ul></li><li><span><a href="#Предобработка" data-toc-modified-id="Предобработка-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка</a></span><ul class="toc-item"><li><span><a href="#Переименование-столбцов" data-toc-modified-id="Переименование-столбцов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Переименование столбцов</a></span></li><li><span><a href="#Корректировка-типов-данных-столбцов" data-toc-modified-id="Корректировка-типов-данных-столбцов-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Корректировка типов данных столбцов</a></span></li><li><span><a href="#Проверка-пропусков" data-toc-modified-id="Проверка-пропусков-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Проверка пропусков</a></span></li><li><span><a href="#Корректировка-столбца-select_stages" data-toc-modified-id="Корректировка-столбца-select_stages-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Корректировка столбца <code>select_stages</code></a></span></li><li><span><a href="#Кодирование-новых-признаков" data-toc-modified-id="Кодирование-новых-признаков-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Кодирование новых признаков</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Матрица-корреляции" data-toc-modified-id="Матрица-корреляции-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Матрица корреляции</a></span></li><li><span><a href="#Анализ-пар-корреляций" data-toc-modified-id="Анализ-пар-корреляций-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Анализ пар корреляций</a></span><ul class="toc-item"><li><span><a href="#Пары-со-связью-&quot;Сильная-положительная&quot;" data-toc-modified-id="Пары-со-связью-&quot;Сильная-положительная&quot;-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Пары со связью "Сильная положительная"</a></span></li><li><span><a href="#Пары-со-связью-&quot;Умеренная-положительная&quot;" data-toc-modified-id="Пары-со-связью-&quot;Умеренная-положительная&quot;-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Пары со связью "Умеренная положительная"</a></span></li><li><span><a href="#Пары-со-связью-&quot;Слабая-положительная&quot;" data-toc-modified-id="Пары-со-связью-&quot;Слабая-положительная&quot;-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Пары со связью "Слабая положительная"</a></span></li><li><span><a href="#Пары-со-связью-&quot;Слабая-отрицательная&quot;" data-toc-modified-id="Пары-со-связью-&quot;Слабая-отрицательная&quot;-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Пары со связью "Слабая отрицательная"</a></span></li><li><span><a href="#Пары-со-связью-&quot;Умеренная-отрицательная&quot;" data-toc-modified-id="Пары-со-связью-&quot;Умеренная-отрицательная&quot;-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Пары со связью "Умеренная отрицательная"</a></span></li><li><span><a href="#Пары-со-связью-&quot;Сильная-отрицательная&quot;" data-toc-modified-id="Пары-со-связью-&quot;Сильная-отрицательная&quot;-4.2.6"><span class="toc-item-num">4.2.6&nbsp;&nbsp;</span>Пары со связью "Сильная отрицательная"</a></span></li><li><span><a href="#Пары-со-связью-&quot;Нулевая(полная,-не-определена)&quot;" data-toc-modified-id="Пары-со-связью-&quot;Нулевая(полная,-не-определена)&quot;-4.2.7"><span class="toc-item-num">4.2.7&nbsp;&nbsp;</span>Пары со связью "Нулевая(полная, не определена)"</a></span></li></ul></li><li><span><a href="#Общий-вывод-по-связям" data-toc-modified-id="Общий-вывод-по-связям-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Общий вывод по связям</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Гипотезы-общие" data-toc-modified-id="Гипотезы-общие-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Гипотезы общие</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-1" data-toc-modified-id="Гипотеза-1-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Гипотеза 1</a></span></li><li><span><a href="#Гипотеза-2" data-toc-modified-id="Гипотеза-2-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Гипотеза 2</a></span></li><li><span><a href="#Гипотеза-3" data-toc-modified-id="Гипотеза-3-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Гипотеза 3</a></span></li></ul></li><li><span><a href="#Гипотезы-по-закрытым-вакансиям" data-toc-modified-id="Гипотезы-по-закрытым-вакансиям-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Гипотезы по закрытым вакансиям</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-4" data-toc-modified-id="Гипотеза-4-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Гипотеза 4</a></span></li><li><span><a href="#Гипотеза-5" data-toc-modified-id="Гипотеза-5-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Гипотеза 5</a></span></li><li><span><a href="#Гипотеза-6" data-toc-modified-id="Гипотеза-6-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Гипотеза 6</a></span></li></ul></li></ul></li><li><span><a href="#Вывод-по-проекту" data-toc-modified-id="Вывод-по-проекту-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Вывод по проекту</a></span></li></ul></div>

# %% [markdown]
# ## Декомпозиция

# %% [markdown]
# 1. Загрузка необоходимых данных,а так же загрузка датасета.
#  - Предварительный обзор данных, включающий анализ пропусков и построение гистограмм частот числовых значений.
# 2. Предобработка, включающая в себя.
#  - Переименования столбцов
#  - Корректировку типов данных
#  - Проверка пропусков
# 3. Кодирование новых признаков. На основе существующих столбцов будут выделены определнные признаки, которые можно будет далее использовать для построения матрицы корреляций.
# 4. EDA, включащая построение матрицы корреляций и изучение полченных данных.
# 5. Фомирование гипотез и их проверка с помощью статистических тестов.
# 6. Выводы

# %% [markdown]
# ## Загрузка библиотек и данных
# [Назад к содержанию](#section_id)

# %%
# !pip install xlrd
# !pip install openpyxl
# !pip install wordcloud
# !pip install phik

# %%
import numpy as np
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns
import phik
import re

from wordcloud import WordCloud
from collections import Counter
from scipy import stats as st

# %%
df = pd.read_excel('...')
pd.set_option('max_columns', None)

# %%
df.head()
# Out:
#     id Статус    Источник лида    Менеджер Дата публикации Дата закрытия  \
# 0   40  Архив        Повторная  менеджер 9      2023-08-30    2023-08-30
# 1  104  Архив  Входящая заявка  менеджер 6      2023-08-22    2023-08-22
# 2  157  Архив      Реферальная  менеджер 9      2023-08-28    2023-10-03
# 3  181  Архив  Входящая заявка         NaN      2023-08-24    2023-08-24
# 4  184  Архив  Входящая заявка         NaN      2023-08-24    2023-08-24
#
#    Количество просмотров  Количество откликов  \
# 0                    153                   35
# 1                    188                    4
# 2                     37                    8
# 3                     33                    7
# 4                     51                   13
#
#                                              Позиция  Зарплата от  \
# 0  Стажёр Python разработчик (неоплачиваемая стаж...          NaN
# 1                             Технический интервьюер          NaN
# 2                                     JS-разработчик          NaN
# 3                                Младший разработчик          NaN
# 4                                   Младший аналитик          NaN
#
#    Зарплата до   Город                                  Формат оформления  \
# 0          NaN  Москва  ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...
# 1          NaN  Москва                                                ГПХ
# 2     100000.0  Москва  ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...
# 3          NaN  Москва  ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...
# 4          NaN  Москва                                   Трудовой договор
#
#   Формат работы                                               Опыт  \
# 0      Удаленка  До 1 года опыта, возможен опыт в pet-проектах;...
# 1      Удаленка  До 1 года опыта, возможен опыт в pet-проектах;...
# 2      Удаленка      До 1 года опыта, возможен опыт в pet-проектах
# 3          Офис  До 1 года опыта, возможен опыт в pet-проектах;...
# 4          Офис  До 1 года опыта, возможен опыт в pet-проектах;...
#
#                                      Образование             Занятость  \
# 0  Другое, На смежных специальностях, Профильное  Проектная, Частичная
# 1  Другое, На смежных специальностях, Профильное             Частичная
# 2  Другое, На смежных специальностях, Профильное                Полная
# 3          На смежных специальностях, Профильное                Полная
# 4          На смежных специальностях, Профильное                Полная
#
#   Ссылка на тестовое                            Обязательные требования  \
# 0                нет  Наш стек: Python, fastapi, postgres, gitlab\nП...
# 1                нет  1) Широкий IT-кругозор, понимание, какие бываю...
# 2                нет  умение самостоятельно разбираться в чужом коде...
# 3                нет  - Высшее IT/техническое образование либо после...
# 4                нет  - ОБЯЗАТЕЛЬНО - Высшее ИТ/техническое образова...
#
#                            Дополнительный требования  \
# 0  Основные требования к ребятам, которые хотели ...
# 1                                                NaN
# 2  Опыт коммерческой разработки на JS будет больш...
# 3  - Базовое понимание объектов БД и их применени...
# 4  Базовое понимание объектов БД и их применение_...
#
#                                         Этапы отбора  \
# 0                     Техническое задание и интервью
# 1  1) тестовое задание\n2) онлайн собеседование с...
# 2  - Отклик с сопроводительным письмом обязательн...
# 3  - Скрининг резюме_x000D_\n- Техническое интерв...
# 4  1. Скрининг резюме_x000D_\n2. Тестовое задание...
#
#                                              Условия
# 0  Школа бесплатна и сотрудничает с фондами.\n\nС...
# 1  ставка 750 рублей - за 1 обработанного кандида...
# 2  - Работа удаленная, оплата в форме оклада.\n- ...
# 3  У нас вы получите возможность:_x000D_\n- Работ...
# 4  Стабильный оклад + премия по итогам года/проек...

# %% [markdown]
# ### Предварительный обзор данных
# [Назад к содержанию](#section_id)

# %% [markdown]
# Для начала предварительно рассмотрим представленные данные. Обратим внимание на:
# -  общий вид таблицы
# -  типы данных
# -  посмотрим наличие пропусков
# -  рассмотрим числовые значения с помощью гистограмм частот и описательных статистик

# %%
def info(df):
    print('Обзор датасета')
    display(df.head()),
    print('Обзор типов данных'),
    display(df.info()),
    print('Обзор пропусков'),
    display(df.isna().sum()),
    print('Обзор числовых значений'),
    display(df.drop('id', axis = 1).describe()),
    print('Гистограммы частот')
    df.drop('id', axis = 1).hist(figsize = (15,10), bins = 50);
info(df)
# Out:
# Обзор датасета
#     id Статус    Источник лида    Менеджер Дата публикации Дата закрытия  \
# 0   40  Архив        Повторная  менеджер 9      2023-08-30    2023-08-30
# 1  104  Архив  Входящая заявка  менеджер 6      2023-08-22    2023-08-22
# 2  157  Архив      Реферальная  менеджер 9      2023-08-28    2023-10-03
# 3  181  Архив  Входящая заявка         NaN      2023-08-24    2023-08-24
# 4  184  Архив  Входящая заявка         NaN      2023-08-24    2023-08-24
#
#    Количество просмотров  Количество откликов  \
# 0                    153                   35
# 1                    188                    4
# 2                     37                    8
# 3                     33                    7
# 4                     51                   13
#
#                                              Позиция  Зарплата от  \
# 0  Стажёр Python разработчик (неоплачиваемая стаж...          NaN
# 1                             Технический интервьюер          NaN
# 2                                     JS-разработчик          NaN
# 3                                Младший разработчик          NaN
# 4                                   Младший аналитик          NaN
#
#    Зарплата до   Город                                  Формат оформления  \
# 0          NaN  Москва  ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...
# 1          NaN  Москва                                                ГПХ
# 2     100000.0  Москва  ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...
# 3          NaN  Москва  ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...
# 4          NaN  Москва                                   Трудовой договор
#
#   Формат работы                                               Опыт  \
# 0      Удаленка  До 1 года опыта, возможен опыт в pet-проектах;...
# 1      Удаленка  До 1 года опыта, возможен опыт в pet-проектах;...
# 2      Удаленка      До 1 года опыта, возможен опыт в pet-проектах
# 3          Офис  До 1 года опыта, возможен опыт в pet-проектах;...
# 4          Офис  До 1 года опыта, возможен опыт в pet-проектах;...
#
#                                      Образование             Занятость  \
# 0  Другое, На смежных специальностях, Профильное  Проектная, Частичная
# 1  Другое, На смежных специальностях, Профильное             Частичная
# 2  Другое, На смежных специальностях, Профильное                Полная
# 3          На смежных специальностях, Профильное                Полная
# 4          На смежных специальностях, Профильное                Полная
#
#   Ссылка на тестовое                            Обязательные требования  \
# 0                нет  Наш стек: Python, fastapi, postgres, gitlab\nП...
# 1                нет  1) Широкий IT-кругозор, понимание, какие бываю...
# 2                нет  умение самостоятельно разбираться в чужом коде...
# 3                нет  - Высшее IT/техническое образование либо после...
# 4                нет  - ОБЯЗАТЕЛЬНО - Высшее ИТ/техническое образова...
#
#                            Дополнительный требования  \
# 0  Основные требования к ребятам, которые хотели ...
# 1                                                NaN
# 2  Опыт коммерческой разработки на JS будет больш...
# 3  - Базовое понимание объектов БД и их применени...
# 4  Базовое понимание объектов БД и их применение_...
#
#                                         Этапы отбора  \
# 0                     Техническое задание и интервью
# 1  1) тестовое задание\n2) онлайн собеседование с...
# 2  - Отклик с сопроводительным письмом обязательн...
# 3  - Скрининг резюме_x000D_\n- Техническое интерв...
# 4  1. Скрининг резюме_x000D_\n2. Тестовое задание...
#
#                                              Условия
# 0  Школа бесплатна и сотрудничает с фондами.\n\nС...
# 1  ставка 750 рублей - за 1 обработанного кандида...
# 2  - Работа удаленная, оплата в форме оклада.\n- ...
# 3  У нас вы получите возможность:_x000D_\n- Работ...
# 4  Стабильный оклад + премия по итогам года/проек...
# Обзор типов данных
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1284 non-null   int64
#  1   Статус                     1284 non-null   object
#  2   Источник лида              1274 non-null   object
#  3   Менеджер                   1193 non-null   object
#  4   Дата публикации            1284 non-null   object
#  5   Дата закрытия              1127 non-null   object
#  6   Количество просмотров      1284 non-null   int64
#  7   Количество откликов        1284 non-null   int64
#  8   Позиция                    1284 non-null   object
#  9   Зарплата от                469 non-null    float64
#  10  Зарплата до                372 non-null    float64
#  11  Город                      1284 non-null   object
#  12  Формат оформления          1284 non-null   object
#  13  Формат работы              1284 non-null   object
#  14  Опыт                       1284 non-null   object
#  15  Образование                1284 non-null   object
#  16  Занятость                  1284 non-null   object
#  17  Ссылка на тестовое         1284 non-null   object
#  18  Обязательные требования    1284 non-null   object
#  19  Дополнительный требования  659 non-null    object
#  20  Этапы отбора               1284 non-null   object
#  21  Условия                    1284 non-null   object
# dtypes: float64(2), int64(3), object(17)
# memory usage: 220.8+ KB
# None
# Обзор пропусков
# id                             0
# Статус                         0
# Источник лида                 10
# Менеджер                      91
# Дата публикации                0
# Дата закрытия                157
# Количество просмотров          0
# Количество откликов            0
# Позиция                        0
# Зарплата от                  815
# Зарплата до                  912
# Город                          0
# Формат оформления              0
# Формат работы                  0
# Опыт                           0
# Образование                    0
# Занятость                      0
# Ссылка на тестовое             0
# Обязательные требования        0
# Дополнительный требования    625
# Этапы отбора                   0
# Условия                        0
# dtype: int64
# Обзор числовых значений
#        Количество просмотров  Количество откликов    Зарплата от  \
# count            1284.000000          1284.000000     469.000000
# mean               40.193146            11.512461   47064.712154
# std                38.710429            12.660222   25321.879938
# min                 1.000000             1.000000       0.000000
# 25%                15.000000             4.000000   30000.000000
# 50%                30.000000             8.000000   40000.000000
# 75%                51.000000            15.000000   60000.000000
# max               317.000000           151.000000  150000.000000
#
#          Зарплата до
# count     372.000000
# mean    74808.911290
# std     41501.835659
# min         0.000000
# 25%     50000.000000
# 50%     65000.000000
# 75%    100000.000000
# max    250000.000000
# Гистограммы частот

# %% [markdown]
# Выводы по предварительном обзору данных:
# - Названия столбцов представлены на русском языке, с использованием верхнего ригистра и пробелов. Так как указано, что заказчик будет ознакомлен только с презентацией, то для собственного удобства переименую столбцы к формату snake_case.
# - Столбцы с датами открытия и закрытия вакансий необходимо привести к соответствующему типу данных.
# - Булевый столбец с наличием тестового задания так же необходимо привести к соответствующему типу данных.
# - Пропуски в столбцах `источник лида`, `менеджер`, `дата закрытия`, `оба зарплатных столбца`, а так же `доп. требования`. Более подробно будут разобраны ниже.
# - 75% вакансий просматриваются до 51 раза, а так имеют в основном до 15 откликов.
# - Средняя нижняя граница зарплатныой вилки находится в районе 47 тыс. руб., средняя верхняя - около 74 тыс. руб.

# %% [markdown]
# ## Предобработка
# [Назад к содержанию](#section_id)

# %% [markdown]
# В данном разделе:
# - переименую столбцы
# - приведу определенные столбцы к нужному типу данных
# - рассмотрю подробнее пропуски
# - рассмотрю подробнее числовые данные после преобразований типов данных

# %% [markdown]
# ### Переименование столбцов
# [Назад к содержанию](#section_id)

# %% [markdown]
# - Источник лида - `source`
# - Менеджер - `manager`
# - Дата публикации - `first_date`
# - Дата закрытия - `last_date`
# - Количество просмотров - `view_count`
# - Количество откликов - `resp_count`
# - Позиция - `vac_name`
# - Зарплата от - `salary_min`
# - Зарплата до - `salary_max`
# - Город - `city`
# - Формат оформления - `law_format`
# - Формат работы - `work_format`
# - Опыт - `exp`
# - Образование - `education`
# - Занятость - `job_time_type`
# - Ссылка на тестовое - `task_link`
# - Обязательные требования - `main_req`
# - Дополнительный требования - `other_req`
# - Этапы отбора - `select_stages`
# - Условия - `conditions`

# %%
df = df.rename(columns={"Статус": "status",
                        "Источник лида": "source",
                        "Менеджер": "manager",
                        "Дата публикации": "first_date",
                        "Дата закрытия": "last_date",
                        "Количество просмотров": "view_count",
                        "Количество откликов": "resp_count",
                        "Позиция": "vac_name",
                        "Зарплата от": "salary_min",
                        "Зарплата до": "salary_max",
                        "Город": "city",
                        "Формат оформления": "law_format",
                        "Формат работы": "work_format",
                        "Опыт": "exp",
                        "Образование": "education",
                        "Занятость": "job_time_type",
                        "Ссылка на тестовое": "task_link",
                        "Обязательные требования": "main_req",
                        "Дополнительный требования": "other_req",
                        "Этапы отбора": "select_stages",
                        "Условия": "conditions",})

# %% [markdown]
# ### Корректировка типов данных столбцов
# [Назад к содержанию](#section_id)

# %% [markdown]
# После корректировки типов данных столбцов с датами, допонительно создам столбец с разницей в днях между датами открытия и закрытия вакансии

# %%
df['first_date']= pd.to_datetime(df['first_date'])
df['last_date']= pd.to_datetime(df['last_date'])
df.insert(6, 'time_delta', (df['last_date'] - df['first_date']) / np.timedelta64 ( 1 , 'D'))

# %% [markdown]
# Перед обработкой убедимся, что в столбце `task_link` нет посторонних значений

# %%
display(df['task_link'].unique())
df['task_link'] = df['task_link'].replace({'да':  1, 'нет':  0})
df['task_link'] = df['task_link'].astype('bool')
df['task_link'].dtype
# Out:
# array(['нет', 'да'], dtype=object)
# dtype('bool')

# %% [markdown]
# ### Проверка пропусков

# %% [markdown]
# [Назад к содержанию](#section_id)

# %%
# Проверим пропуски в датасете
display(pd.concat(
    [
        df.isna().sum(),
        df.isna().mean().apply('{:.4%}'.format)
    ], axis=1,
    keys=['nan_count', 'nan_share']
).sort_values(by='nan_count', ascending=False))
# Out:
#                nan_count nan_share
# salary_max           912  71.0280%
# salary_min           815  63.4735%
# other_req            625  48.6760%
# last_date            157  12.2274%
# time_delta           157  12.2274%
# manager               91   7.0872%
# source                10   0.7788%
# work_format            0   0.0000%
# select_stages          0   0.0000%
# main_req               0   0.0000%
# task_link              0   0.0000%
# job_time_type          0   0.0000%
# education              0   0.0000%
# exp                    0   0.0000%
# id                     0   0.0000%
# law_format             0   0.0000%
# city                   0   0.0000%
# status                 0   0.0000%
# vac_name               0   0.0000%
# resp_count             0   0.0000%
# view_count             0   0.0000%
# first_date             0   0.0000%
# conditions             0   0.0000%

# %% [markdown]
# Рассмотрим подробнее пропуски:
# - 71% и 63% - `salary_max` и `alary_min` соответственно, самые большие проценты пропусков. Пропуски в условиях зарплаты можно объяснить тем, что вохможно работодатель ожидает от соискателя определенных условий, на основе которых ему лечге принять решение о том, подходит ли соискатель.
# - 48% - `other_req`. Возможно требования к вакансии уже изложены как обязательные.
# - 12% - `last_date` и `time_delta`. У открытых вакансий нет еще срока закрытия, что логично. Дельта в таких вакансиях так же не может быть посчитана.
# - `manager` - 7%. Согласно комментария заказчика возможны пустые значения в связи с тем, что это поле сначала не существовало, потом было не обязательным к заполнению.
# - `source` - 0,7%. Всего 10 строк с вакансиями без источника лида. Проверим, что они из себя представляют

# %%
df.query('source.isna()')
# Out:
#       id           status source     manager first_date  last_date  \
# 5    281     Закрыта нами    NaN  менеджер 9 2023-01-09 2023-01-24
# 12   288            Архив    NaN         NaN 2023-01-11 2023-03-02
# 16   295            Архив    NaN         NaN 2023-01-12 2023-03-04
# 21   302            Архив    NaN         NaN 2023-01-16 2023-02-08
# 22   303            Архив    NaN         NaN 2023-01-16 2023-03-02
# 71   367     Закрыта нами    NaN  менеджер 2 2023-01-27 2023-03-02
# 75   372        Отклонена    NaN         NaN 2023-01-30 2023-02-13
# 80   378        Отклонена    NaN         NaN 2023-01-30 2023-02-13
# 116  428  На рассмотрении    NaN         NaN 2023-02-13        NaT
# 143  464  На рассмотрении    NaN         NaN 2023-02-22        NaT
#
#      time_delta  view_count  resp_count  \
# 5          15.0          29           6
# 12         50.0          12           1
# 16         51.0          14           2
# 21         23.0          18           2
# 22         45.0          17           2
# 71         34.0          10           6
# 75         14.0          33          23
# 80         14.0          44           3
# 116         NaN          51          16
# 143         NaN          96          45
#
#                                               vac_name  salary_min  \
# 5                       Фронтенд разработчик на проект         NaN
# 12                                         PR-менеджер         NaN
# 16                                 Стажер SMM проектов         0.0
# 21       Руководитель проектов по рекламе (маркетолог)     30000.0
# 22                                 Интернет-маркетолог     70000.0
# 71   Frontend-разработчик в подразделение комплексн...         NaN
# 75                                         IT-рекрутер     50000.0
# 80                                     Project manager     40000.0
# 116                                Интернет-маркетолог         NaN
# 143                                 Стажер-тестировщик         NaN
#
#      salary_max                                               city  \
# 5       19000.0                                     Ростов-на-Дону
# 12          NaN                                             Москва
# 16          0.0                                             Москва
# 21      60000.0                                          Челябинск
# 22      90000.0                                             Москва
# 71          NaN  Москва, Санкт-Петербург, Хабаровск, Иннополис,...
# 75      80000.0                                             Москва
# 80      50000.0                                             Москва
# 116         NaN                                             Москва
# 143         NaN                                             Москва
#
#                                             law_format       work_format  \
# 5                                    Самозанятость, ИП          Удаленка
# 12   ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...      Офис, Гибрид
# 16   ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...          Удаленка
# 21   ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...          Удаленка
# 22   ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...              Офис
# 71   ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...      Офис, Гибрид
# 75   ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...  Гибрид, Удаленка
# 80   ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...  Гибрид, Удаленка
# 116                   Самозанятость, Контракт, ИП, ГПХ          Удаленка
# 143  ИП, ГПХ, Самозанятость, Контракт, Трудовой дог...          Удаленка
#
#                                                    exp  \
# 5    До 1 года опыта, возможен опыт в pet-проектах;...
# 12   До 1 года опыта, возможен опыт в pet-проектах;...
# 16   До 1 года опыта, возможен опыт в pet-проектах;...
# 21   До 1 года опыта, возможен опыт в pet-проектах;...
# 22   До 1 года опыта, возможен опыт в pet-проектах;...
# 71                                      Опыт от 1 года
# 75   До 1 года опыта, возможен опыт в pet-проектах;...
# 80   До 1 года опыта, возможен опыт в pet-проектах;...
# 116  До 1 года опыта, возможен опыт в pet-проектах;...
# 143  До 1 года опыта, возможен опыт в pet-проектах;...
#
#                                          education  \
# 5    Другое, На смежных специальностях, Профильное
# 12   Другое, На смежных специальностях, Профильное
# 16   Другое, На смежных специальностях, Профильное
# 21   Другое, На смежных специальностях, Профильное
# 22   Другое, На смежных специальностях, Профильное
# 71   Другое, На смежных специальностях, Профильное
# 75   Другое, На смежных специальностях, Профильное
# 80   Другое, На смежных специальностях, Профильное
# 116  Другое, На смежных специальностях, Профильное
# 143  Другое, На смежных специальностях, Профильное
#
#                         job_time_type  task_link  \
# 5                           Проектная      False
# 12                             Полная      False
# 16   Стажировка, Проектная, Частичная      False
# 21                             Полная      False
# 22                             Полная      False
# 71                             Полная      False
# 75                  Частичная, Полная      False
# 80                             Полная       True
# 116              Проектная, Частичная      False
# 143     Стажировка, Частичная, Полная      False
#
#                                               main_req  \
# 5    - владение JavaScript,_x000D_\n- готовность к ...
# 12   — Заряд энергии и организаторские способности:...
# 16   🔸базовые знания в составлении стратегии продви...
# 21   — опыт работы в сфере интернет-маркетинга от 2...
# 22   - Понимание основ маркетинга_x000D_\n- Владени...
# 71   •Знание JavaScript, в том числе современного с...
# 75   - знание методики первичного отбора кандидатов...
# 80   Знание процесса разработки IT-продуктов (agile...
# 116  - навыки работы с каналами контекстной, таргет...
# 143  - Знание методик тестирования_x000D_\n- Англий...
#
#                                              other_req  \
# 5                                                  NaN
# 12                                                 NaN
# 16                                                 NaN
# 21                                                 NaN
# 22                   Знание CMS Word Press, Битрикс 24
# 71   • Хорошее понимание клиент-серверного взаимоде...
# 75   Желательно чтобы в образовании были навыки выс...
# 80   Наличие высшего образования, наличие курсов по...
# 116  - навыки работы с РСЯ, Google Display, в CPA_x...
# 143                                                NaN
#
#                                          select_stages  \
# 5    1. Скрининг портфолио_x000D_\n2. Собеседование...
# 12   — Телефонное интервью -> Тестовое задание -> З...
# 16                      Скрининг резюме, собеседование
# 21   - Скрининг резюме_x000D_\n- Собеседование_x000...
# 22   1) телефонное интервью_x000D_\n2) интервью в о...
# 71   1. Скрининг резюме и гита_x000D_\n2. Тестовое ...
# 75   1. Скрининг резюме_x000D_\n2. Созвон с командо...
# 80   1. Скрининг резюме_x000D_\n2. Телефонное интер...
# 116  - скрининг резюме_x000D_\n- собеседование_x000...
# 143  - Анкета после одобрения резюме_x000D_\n- Звон...
#
#                                             conditions
# 5    Стек: JavaScript _x000D_\nСрок выполнения: 15 ...
# 12   — Возможность развития в российском и междунар...
# 16   Длительность стажировки: 6 недель, будьте гото...
# 21   — одновременно в работе до 6 проектов;_x000D_\...
# 22   - Оформление по ТК РФ, график работы 5/2;_x000...
# 71   • Готовы рассматривать джунов с опытом_x000D_\...
# 75   - Можно полностью удаленно, можно гибрид _x000...
# 80   - г.Москва, ст.м. Дмитровская, ул. Складочная ...
# 116  - полностью удаленная работа _x000D_\n- частич...
# 143  - Удаленная работа_x000D_\n- 2-3 месяца оплачи...

# %% [markdown]
# Из 10 вакансий всего две находятся на рассмотрении, остальные закрыты, отклонены. в архиве. Возможно по ошибке не были подгружены данные по источнику.

# %% [markdown]
# Так же можно сказать, что у нас всего 303 вакансии, где указана полная зарплатная вилка.

# %%
df.query('~salary_max.isna() & ~salary_min.isna()').id.count()
# Out:
# 303

# %%
df.query('salary_max.isna() & salary_min.isna()').id.count()
# Out:
# 746

# %% [markdown]
# ### Корректировка столбца `select_stages`
# [Назад к содержанию](#section_id)

# %% [markdown]
# В столбце `select_stages` есть символы _x000D_ и \n - специальные символы, которые были вставлены в процессе экспорта данных из Excel в pandas DataFrame. Очистим данные от этих символов, чтобы читалось удобнее.

# %%
df.select_stages.unique()
# Out:
# array(['Техническое задание и интервью',
#        '1) тестовое задание\n2) онлайн собеседование с менеджером проектов\n3) онлайн собеседование с СОО или СЕО',
#        '- Отклик с сопроводительным письмом обязательно! Коротко рассказать о себе (навыки, заслуги, увлечения), о проектах, в которых довелось участвовать, о своей мотивации на компанию и задачи\n- Собеседование (обычно оно проходит в текстовом или голосовом режиме в Telegram).\n- Тестовое задание в срок, который вы сами себе установите.\n- Решение',
#        '- Скрининг резюме_x000D_\n- Техническое интервью с HR_x000D_\n- Интервью с тех. специалистом_x000D_\n- ДЗ_x000D_\n- Интервью с тимлидом/руководителем',
#        '1. Скрининг резюме_x000D_\n2. Тестовое задание_x000D_\n3.   Интервью',
#        '1. Скрининг портфолио_x000D_\n2. Собеседование с руководителем направления и hr-менеджером',
#        '1. Скрининг резюме (важно аккуратное оформление и мотивация - пишите сопроводительное письмо с причинами, почему вам интересно здесь работать),_x000D_\n2. Заполнение анкеты с вопросами на логику_x000D_\n3. Интервью с рекрутером_x000D_\n4. Интервью с командой_x000D_\n_x000D_\n_x000D_\nВАЖНО:_x000D_\nНесмотря на то, что здесь требуется разговорный английский язык, резюме примут на английском или русском языке - на этапе отбора работают русскоязычные рекрутеры.',
#        '1. Собеседование HR удаленно_x000D_\n2. Собеседование в офисе с тим лидом',
#        '1. Отклик_x000D_\n2. Тестовое задание_x000D_\n3. Просмотр резюме и тестового _x000D_\n4. Одно собеседование с HR-менеджером, руководителем и директором направления _x000D_\n5.Решение',
#        '- интервью',
#        '1) Первичный скрининг_x000D_\n2) Тестовое задние_x000D_\n3) Финальное собеседование',
#        'Скрининг резюме, собеседование, возможно тестовое.',
#        '— Телефонное интервью -> Тестовое задание -> Знакомство с руководителем -> согласование оффера._x000D_\n_x000D_\nЭтапы займут не более 7 дней и подробный фидбек дается после каждого этапа._x000D_\n_x000D_\n*Тестовое задание присылается кандидатам без опыта, с опытными кандидатами ведется общение по проектам',
#        'Скрининг резюме, сопроводительное письмо, собеседование, возможно тестовое.',
#        '1. просмотр резюме_x000D_\n2. первичное интервью_x000D_\n3. интервью с директором департамента_x000D_\n4. тестовое задание объемом не более 2 часов (опционально)_x000D_\n5. финальное интервью по результатам тестового задания (опционально)',
#        'Скрининг резюме, собеседование',
#        'Скрининг резюме_x000D_\nТестовое задание_x000D_\nИнтервью',
#        '1. Скрининг_x000D_\n2. Интервью',
#        '1. Скрининг_x000D_\n2. Собеседование с рекрутером_x000D_\n3. Возможно тестовое задание_x000D_\n4. Собеседование с руководителем',
#        '- Скрининг резюме_x000D_\n- Собеседование_x000D_\n- Возможно тестовое',
#        '1) телефонное интервью_x000D_\n2) интервью в офисе с руководителем',
#        '1. скрининг резюме_x000D_\n2. лайвкодинг и техсобес около получаса_x000D_\n3. встреча с тимлидом по оставшимся вопросам_x000D_\n4. вводные/пробные 3 оплачиваемых дня в офисе_x000D_\n5. оффер',
#        '1. Скрининг резюме _x000D_\n2. Созвон с менеджером _x000D_\n3. Тестовое (с успешными)_x000D_\n4. Офлайн-встреча',
#        '1. Скрининг резюме _x000D_\n2. Звонок',
#        '1. Скрининг резюме, _x000D_\n2. Интервью с рекрутером_x000D_\n3. Возможно тестовое задание_x000D_\n4. Интервью с командой',
#        '1. Скрининг резюме_x000D_\n2. Интервью + техническое собеседование',
#        '1. Скрининг _x000D_\n2. Интервью с рекрутером_x000D_\n3. Тестовое задание _x000D_\n4. Интервью с командой',
#        '1. Скрининг резюме_x000D_\n2. Интервью с руководителем и командой Центра Продуктового Управления Дирекции по Цифровой Трансформации, 3. тестовое задание (возможно, этап будет пропущен).',
#        '1) Просмотр GitHub кандидата,_x000D_\n2) Небольшой созвон в Skype/Teams/Zoom/Телемосте - разработчик расскажет о том, чего хочет от кандидата и попросит его рассказать о работе с ревьюверами на курсе._x000D_\n_x000D_\nВ течении 72 часов принимается решение и дается обратная связь.',
#        '1. Скрининг резюме _x000D_\n2.  Тестовое задание _x000D_\n3. Собеседование на русском и английском языке_x000D_\n4. Испытательные дни в студии (оплачиваются, 3-4 дня)_x000D_\n_x000D_\nВыход на стажировку (3 месяца) с возможностью  дальнейшего трудоустройства',
#        '1) Скрининг резюме_x000D_\n2) Собеседование по хард и софт-скиллам_x000D_\n3) Беседа с психологом компании',
#        '1. Скрининг резюме _x000D_\n2. Техническое собеседование',
#        '1. Скрининг резюме _x000D_\n2. Созвон _x000D_\n3. Тестовое _x000D_\n4. Финальный созвон',
#        'Очное интервью с руководителем',
#        '1. Скрининг резюме _x000D_\n2. Звонок-встреча_x000D_\n3. Тестирование',
#        'Интервью _x000D_\nТестовое задание (если есть вопросы по портфолио)',
#        'При отклике на вакансию пришлите нам во внутренний чат hh.ru сопроводительное письмо с примерами написанного вами кода._x000D_\n_x000D_\nОтветным сообщением мы вышлем вам ссылку на тестовое задание._x000D_\n_x000D_\nЕсли задание выполнено успешно: назначаем собеседование с CTO ~ 30 минут._x000D_\n_x000D_\nЧерез несколько дней принимаем решение и даем обратную связь.',
#        '1. Скрининг _x000D_\n2. Интервью с рекрутером_x000D_\n3. Интервью с командой',
#        '1) Скрининг резюме (гитхаб + сопроводительное)_x000D_\n2) Тестовое_x000D_\n2) Собес с СТО',
#        'Интервью с руководителем',
#        'Интервью с командой_x000D_\n_x000D_\nЕсли эта вакансия для тебя, то в сопроводительном письме ответь на три вопроса:_x000D_\n1. Почему хочешь работать именно в нашей компании?_x000D_\n2. Что хочешь получить от работы с нами?_x000D_\n3. Твоя идеальная команда?_x000D_\n_x000D_\n*отклики без сопроводительного письма не рассматриваем!',
#        '1. Скрининг резюме_x000D_\n2. Тестовое задание_x000D_\n3. Первый этап интервью_x000D_\n4. Финальный этап интервью',
#        '1. Скрининг резюме _x000D_\n2. Звонок с командой',
#        '1. Скрининг_x000D_\n2.Интервью с рекрутером_x000D_\n3. Интервью с командой',
#        'Интервью с командой',
#        '- Интервью с руководителем_x000D_\n- Стажировочный день (3-4 часа)',
#        '1. Скрининг резюме _x000D_\n2. Личная встреча в офисе _x000D_\n3. Тестовое задание _x000D_\n4. Тестовый день',
#        '1. Скрининг резюме _x000D_\n2. Тестовое задание _x000D_\n3. Личная встреча в офисе',
#        '1. Скрининг_x000D_\n2. Интервью с рекрутером_x000D_\n3. Интервью с командой',
#        'Интервью_x000D_\nТестовое задание',
#        '1. телефонное интервью с рекрутером_x000D_\n2. техническое собеседование с лидом_x000D_\nВ сопроводительном письме обязательно присылай свой профиль в TenChat, будем на связи!',
#        '1) скрининг резюме_x000D_\n2) техническое и софт-скилловое собеседование',
#        '1) Звонок с интервьюром_x000D_\n2) Интервью с нанимающим менеджером_x000D_\n3) Пробный день в офисе',
#        '1. Скрининг резюме (важно аккуратное оформление и мотивация - пишите сопроводительное письмо с причинами, почему вам интересно здесь работать),_x000D_\n2. Заполнение анкеты с вопросами на логику_x000D_\n3. Интервью с рекрутером_x000D_\n4. Интервью с командой',
#        '1. Скрининг резюме _x000D_\n2. Собеседование с техническим экспертом_x000D_\n3. Анкета',
#        'Интервью с руководителем_x000D_\n_x000D_\nНапиши нам о себе, о своем опыте, навыках и увлечениях, а также не забудь написать пожелания по уровню заработной платы.',
#        'Для отклика, пожалуйста, заполните форму: https://forms.gle/voB5Q6X81KpPYTRy5',
#        '1. Скрининг резюме_x000D_\n2. Собеседование с рекрутером',
#        '- Просмотр резюме_x000D_\n- Техническое собеседование_x000D_\n- Возможно тестовое задание',
#        'Тестовое задание_x000D_\nСобеседование (с руководителем направления)_x000D_\nИспытательный срок (месяц) - оплачивается',
#        '1. Скрининг портфолио_x000D_\n2. Интервью',
#        '1 Презентация о себе и своих навыках_x000D_\n2 Очное интервью (возможно тестирование)_x000D_\n3 Финальное интервью',
#        '1. Скрининг резюме_x000D_\n2. Тестовое задание_x000D_\n3. Собеседование с HR и с руководителем подбора (онлайн)_x000D_\n4. Собеседование с исполнительным и генеральным директором (онлайн)',
#        '1. Скрининг резюме _x000D_\n2. Собеседование с HR (онлайн) _x000D_\n3. Тестовое задание, которое необходимо выполнить за 24 часа. _x000D_\n4. Техническое собеседование (online или в офисе)',
#        '1.Скрининг резюме _x000D_\n2.Собеседование с HR_x000D_\n3.Тестовое _x000D_\n4.Стажировка',
#        '1. Скрининг резюме и гита_x000D_\n2. Тестовое опционально_x000D_\n3. Собеседование с лидом компетенций_x000D_\n4. Собеседование с диром департамента опционально',
#        '1. Скрининг резюме_x000D_\n2. Интервью №1_x000D_\n2. Интервью №2',
#        '1. Скрининг резюме _x000D_\n2. Интервью с тимлидом, _x000D_\n3. Обучение - пробный месяц стажировки',
#        '1) Скрининг резюме_x000D_\n2) Интервью с исполнительным директором_x000D_\n3) Техническое собеседование с командой',
#        '1. Скрининг резюме_x000D_\n2. Созвон с командой (разговор по телефону)_x000D_\n3. Финальное интервью',
#        '1. Скрининг резюме _x000D_\n2. Техническое интервью',
#        '1 этап - тел. интервью_x000D_\n2 этап - 1 собеседование_x000D_\n3 этап - тестовое задание _x000D_\n4 этап - финальное интервью',
#        'Очное интервью с руководителем компании',
#        '1. Скрининг резюме_x000D_\n2. Телефонное интервью с HR_x000D_\n3. Тестовое задание_x000D_\n4. Онлайн интервью с Senior PM и Product lead',
#        '1. Просмотр резюме, портфолио. _x000D_\n2. Собеседование _x000D_\n3. Возможно тестовое задание',
#        '1 Презентация о себе и своих навыках_x000D_\n2 В офисе интервью (мб тестирование)_x000D_\n3 Финальное интервью',
#        '1. Скрининг резюме _x000D_\n2. Личное общение с кандидатом/встреча с командой.',
#        '- Телефонный созвон с HRD _x000D_\n- Интервью в zoom с командой_x000D_\nЕсли тебя заинтересовала наша вакансия, пожалуйста, расскажи о своем самом большом профессиональном достижении в сопроводительном письме.',
#        '1. Чтобы попасть в команду нужно круто справиться с тестовым заданием, его отправим после отклика._x000D_\n2. Интервью с командой',
#        'Тестовое задание_x000D_\nИнтервью',
#        '1. Скрининг_x000D_\n2. Интервью с рекрутером_x000D_\n3. Тестовое задание_x000D_\n4. Интервью с руководителем/командой',
#        '1) Смотрим портфолио;_x000D_\n2) Зовем на знакомство и даем тестовое;_x000D_\n3) Получаем тестовое и даем обратную связь;_x000D_\n4) Встреча с CEO и CMO;_x000D_\n5) Офер.',
#        '1. Скрининг резюме _x000D_\n2. Интервью с HR _x000D_\n3. Финальное интервью',
#        '1. Скрининг резюме_x000D_\n2. Общение с руководителем',
#        '1) скрининг резюме_x000D_\n2) 3 технические секции_x000D_\n3) финальное знакомство с командой',
#        'Интервью с HR',
#        '1. Скрининг резюме_x000D_\n2. HR интервью_x000D_\n3. Интервью с руководителем',
#        'короткое тестовое_x000D_\nсобеседование (очное)_x000D_\nиспытательный срок._x000D_\n_x000D_\nТестовое задание будет заключаться в проработке кейса (например: готовится к запуску большая профильная научная конференция, необходимо создать стратегию продвижения материалов этой конференции, ее бренда).',
#        '1. Скрининг резюме _x000D_\n2. Интервью с рекрутером_x000D_\n3. Тестовое задание_x000D_\n4. Техническое интервью_x000D_\n5. Интервью с командой',
#        'Скрининг, анализ портфолио, сопоставление с заявленными требованиями и проведение собеседования.',
#        '- cкрининг_x000D_\n- интервью',
#        '- скрининг _x000D_\n- собеседование с руководителем группы подбора',
#        '1. Скрининг резюме _x000D_\n2. Созвон_x000D_\n3. Тестовое _x000D_\n4. Встреча (офис)',
#        '1. скрининг - 30 минут (звонок без видео)_x000D_\n2. Тестовое задание (2 дня на выполнение)_x000D_\n3. Встреча с руководителем команды (зум 45 минут)_x000D_\n4. Оффер',
#        '- Интервью с рекрутером_x000D_\n- Тестовое задание_x000D_\n- Интервью с руководителем',
#        '- скрининг резюме и сопроводительного + портфолио проектов _x000D_\n- собеседование',
#        'Скрининг резюме_x000D_\nИнтервью',
#        'Если тебя заинтересовала эта вакансия, не забудь написать краткое сопроводительное письмо и приложить ссылки на свои лучшие работы.',
#        '1. Скрининг_x000D_\n2. Звонок с рекрутером_x000D_\n3. Интервью с руководителем_x000D_\n4. Возможно тестовое задание',
#        '- скрининг резюме_x000D_\n- собеседование _x000D_\n- возможно тестовое',
#        '1) созвон на 30 минут - знакомство_x000D_\n2) техническое интервью _x000D_\n3) интервью с директором',
#        '1) Скрининг_x000D_\n2) Интервью с hr по телефону_x000D_\n3) Техническое интервью с тех директором и руководителем отдела',
#        '1. Отклик в трекере и анкета от рекрутера. Мы откликаемся на релевантные резюме в среднем в течение 3-5 дней. _x000D_\n2. Возможно тестовое задание_x000D_\n3. Собеседование с руководителем. Проходит в Zoom длительностью до 60 мин.',
#        '- скрининг резюме_x000D_\n- собеседование_x000D_\n- возможно тестовое',
#        '- Скрининг резюме_x000D_\n- Тестовое задание_x000D_\n- Собеседование',
#        '1. Скрининг резюме _x000D_\n2. Беседа об общей заинтересованности._x000D_\n3. Беседа после поверхностного анализа кандидатом рекламных кабинетов компании и изучения сайтов компании.',
#        'Онлайн и офлайн интервью с командой и лидами',
#        '1. Видео-задание: просим ответить на 3 вопроса в формате короткого видео_x000D_\n2. Телефонный скрининг_x000D_\n3. Онлайн интервью_x000D_\n4. Интервью в офисе',
#        'Первичное интервью_x000D_\nТестовое задание_x000D_\nФинальное интервью',
#        '1. Отбор резюме_x000D_\n2. Собеседование с HR и руководителем направления',
#        '- первичное интервью, _x000D_\n- интервью с руководителем, _x000D_\n- интервью с Тим/тех лидом',
#        '1. Скрининг резюме_x000D_\n2. Собеседование',
#        '- предварительное hr интервью (от 15 до 30 минут);_x000D_\n- техническое интервью (от 40 до 60 минут)',
#        'Интервью с HRD_x000D_\nИнтервью с фаундерами',
#        'Скрининг_x000D_\nТестовое_x000D_\nИнтервью',
#        'HR-собеседование;_x000D_\nтестовое задание;_x000D_\nвстреча с командой',
#        'Пожалуйста, в сопроводительном письме ответь на следующие вопросы:_x000D_\n_x000D_\nКакое твоё одно самое значимое достижение?_x000D_\nПочему ты хочешь попасть на нашу стажировку?',
#        '- скрининг _x000D_\n- собеседование',
#        '- скрининг резюме и сопроводительного письма _x000D_\n_x000D_\nЕсли ты решил откликнуться на вакансию, то ответь, пожалуйста, на несколько вопросов в анкете — это поможет нам лучше понять, насколько ты подходишь на эту позицию._x000D_\nПостарайся быть максимально честным, тогда в случае несовпадения — мы не потратим оба слишком много времени, чтобы это осознать._x000D_\n_x000D_\nАнкета для отклика на вакансию: https://forms.gle/kQx8owB2xaS8eKUn9_x000D_\n_x000D_\n! РЕЗЮМЕ ЛУЧШЕ ЗАДУБЛИРОВАТЬ! ОТПРАВИТЬ КАК ЧЕРЕЗ ТРЕКЕР, ТАК И В АНКЕТЕ',
#        '1. Скрининг_x000D_\n2. Созвон с рекрутером_x000D_\n3. Интервью с нанимающим менеджером',
#        '1. просмотр откликов_x000D_\n2. выбор претендентов на собеседование_x000D_\n3. собеседование_x000D_\n4. приём, оформление',
#        '1. Резюме _x000D_\n2. Собеседование-знакомство и небольшое тех интервью (онлайн)_x000D_\n3. Финальный разговор (если получится офлайн - отлично)',
#        '1. Отклик в трекере_x000D_\n2. Заполнение Гугл формы с тестовым заданием - https://forms.gle/hKqknPCQfZphFpez5_x000D_\n3. Скрининг резюме._x000D_\n4. Интервью со старшим IT рекрутером._x000D_\n5. Встреча с командой._x000D_\n6.  Встреча с руководителем отдела рекрутмента.',
#        '1) Отклик с Сопроводительным письмом (обязательно с обозначением, чем интересен проект и компания!)_x000D_\n2) Интервью с Тех лидом/Собственником на 1,5 часа',
#        '1. Скрининг резюме _x000D_\n2. Собеседование _x000D_\n3. Тестовое задание (опционально)',
#        '- Анкета после одобрения резюме_x000D_\n- Звонок с QA и СТО_x000D_\n- Оффер',
#        '1. Скрининг_x000D_\n2. Интервью с рекрутером_x000D_\n3. Интервью с нанимающим менеджером',
#        '1. Первичное телефонное интервью с рекрутером._x000D_\n2. Первое техническое интервью._x000D_\n3. Интервью с рекрутером._x000D_\n4. Второе техническое интервью.',
#        '1. Скрининг резюме_x000D_\n2. Выполнение тестового задания _x000D_\n(срок на выполнение 5 рабочих дней) _x000D_\n3. Общение с руководителем',
#        'Собеседование, стажировка (возможно), испытательный срок (2 месяца)',
#        'Интервью с командой_x000D_\n_x000D_\nЕсли вы хотите стать частью нашей команды — откликнитесь на вакансию. В сопроводительном письме напишите 3 позиции, которые вы нанимали._x000D_\n_x000D_\nТак мы поймем, что вы внимательны и профессионально подходите к вопросу.',
#        'Интервью с рекрутером_x000D_\nИнтервью с лидом направления (+ задачки на логику)_x000D_\nВ сопроводительном письме обязательно присылай свой профиль в TenChat',
#        '1. Скрининг резюме _x000D_\n2. Звонок с HR_x000D_\n3. Звонок с руководителем _x000D_\n4. Тестовое Задание',
#        '1. Скрининг резюме _x000D_\n2. Созвон с лидом_x000D_\n3, Тестовое',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с HR. _x000D_\n3. Возможно тестовое задание. _x000D_\n4. Собеседование с тим-/техлидом.',
#        '1. Скрининг резюме _x000D_\n2. Тестовое Задание _x000D_\n3. Тех Интервью',
#        'Интервью с HR_x000D_\nИнтервью с руководителем направления',
#        '1. Скрининг резюме_x000D_\n2. Одно собеседование по софтскилам и техническое вместе._x000D_\n3. Финальное собеседование с кем то из команды.',
#        '1. Скрининг резюме;_x000D_\n2. Собеседование с HR;_x000D_\n3. Собеседование с руководителем компании.',
#        '- скрининг резюме_x000D_\n- собеседование',
#        '1. Собеседование в ZOOM._x000D_\n2. Очное знакомство в офисе.',
#        '1. Скрининг_x000D_\n2. Интервью с основателем',
#        '1. Скрининг резюме._x000D_\n2. Собеседование с HR._x000D_\n3. Собеседование с руководителем команды.',
#        '- Интервью с командой (секции: техника, опыт работы, ответы на вопросы кандидата). Если пройдёт успешно, дальше интервью с нашим кофаундером. На этом всё)',
#        '1. Скрининг резюме_x000D_\n2. Собседование',
#        '1. Скрининг резюме_x000D_\n2. Интервью с рекрутером_x000D_\n3. Возможно тестовое задание_x000D_\n4. Финальное интервью',
#        '- скрининг_x000D_\n- собеседование',
#        '1. Скрининг резюме. _x000D_\n2. Тестовое задание._x000D_\n3. Собеседование с тимлидом QA_x000D_\n4. Собеседование с руководителями компании',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с HR._x000D_\n3 Собеседование с тимлидом.',
#        '1. Скрининг резюме _x000D_\n2. Собеседование с HR_x000D_\n3. Собеседование с руководителем/командой',
#        '1. Скрининг резюме _x000D_\n2. Собеседование с HR_x000D_\n+ возможно тестовое_x000D_\n3. Собеседование с руководителем/командой',
#        '1. Скрининг резюме _x000D_\n2. Собеседование с лидом',
#        '1. Первичный скрининг резюме; _x000D_\n2. Собеседование с отделом разработки',
#        '1. Выполнение тестового задания._x000D_\n2. Заполнение гугл-формы. _x000D_\n3. Отклик в Карьерном Трекере. _x000D_\n4. Скрининг резюме. _x000D_\n5. Самостоятельное изучение возможностей сервиса и презентация на собеседовании. _x000D_\n6. Стажировка 2 недели.',
#        '1. Скрининг резюме _x000D_\n2. Прохождение теста от работодателя по софт скиллам_x000D_\n3. Техническое интервью',
#        '1. Выполнение тестового задания._x000D_\n2. Заполнение гугл-формы. _x000D_\n3. Отклик в Карьерном Трекере. _x000D_\n4. Скрининг резюме. _x000D_\n5. Собеседование, на котором вы показываете базовые знания нашего продукта._x000D_\n6. Стажировка 2 недели.',
#        '- скрининг_x000D_\n- собеседование_x000D_\n- техническое собеседование',
#        '1. Скрининг резюме_x000D_\n2. Интервью с лидом команды_x000D_\n3. Финал',
#        '1. Оценка резюме и портфолио._x000D_\n2. Первичное интервью._x000D_\n3. Техническое собеседование',
#        '1. Выполнение тестового задания. _x000D_\n2. Отклик в Карьерном трекере. _x000D_\n3. Скрининг резюме. _x000D_\n4. Собеседование с тимлидом.',
#        '1. Отклик в Карьерном трекере._x000D_\n2. Заполнение Гугл формы от работодателя._x000D_\n3. Выполнение тестового задания. _x000D_\n4. Стажировка 2 недели.',
#        '1) Тестовое задание (выдается "В руки");_x000D_\n2) Собеседование;_x000D_\n3) Найм.',
#        '1. Скрининг резюме _x000D_\n2. Тестовое Задание_x000D_\n3. Звонок-собеседование',
#        '1. Первичный отбор резюме._x000D_\n2. Собеседование с отделом разработки',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование по телефону с HR._x000D_\n3. Собеседование в офисе генеральным директором компании.',
#        '1. Скрининг резюме._x000D_\n2. Собеседование в офисе._x000D_\n3. Возможно тестовое задание.',
#        '1. скрининг резюме _x000D_\n2. интервью с рекрутером_x000D_\n3. возможно тестовое задание_x000D_\n4. интервью с руководителем',
#        'Вместе с резюме ждём ответы на небольшое тестовое задание, прикрепи ответы к сопроводительному письму:_x000D_\n_x000D_\n1. Что такое релевантность в контекстной рекламе?_x000D_\n2. По какой формуле рассчитывается средний % кликабельности (ctr)?_x000D_\n3. Как называется сервис для оценки пользовательского интереса и подбора ключевых фраз? (выбери один правильный ответ)_x000D_\n- Roistat_x000D_\n- Wordstat_x000D_\n- Яндекс Метрика',
#        'Техническое и FIT интервью',
#        '1. Скрининг резюме. _x000D_\n2. Интервью с HR._x000D_\n3. Интервью с тимлидом. _x000D_\n4. Возможно тестовое задание.',
#        '1. Скрининг резюме _x000D_\n2. Тестовое Задание _x000D_\n3. Демонстрация тестового задания по одному экрану',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с HR.',
#        'Интервью с руководителем компании_x000D_\n_x000D_\nЗдорово, если к отклику приложите примеры вашего контента, который нравится вам. Не обязательно, чтобы это был коммерческий контент.',
#        '1) заполнение анкеты _x000D_\nhttps://forms.gle/mS9AS1Rv6Qz8nWUj9_x000D_\n_x000D_\n2) выполнение тестового задания_x000D_\n3) собеседование с владельцем _x000D_\n4) испытательный срок/стажировка _x000D_\n(От 1 недели до месяца)',
#        '1. Скрининг резюме _x000D_\n2. Звонок с лидом _x000D_\n3. Личная встреча с командой финальная',
#        '2 этапа:_x000D_\n-зум с потенциальным руководителем;_x000D_\n-зум с руководителем IT подбора.',
#        '- скрининг резюме с тестовым заданием _x000D_\n- собеседование с нанимающим менеджером _x000D_\n_x000D_\nТестовое задание: _x000D_\nПредложить заголовок и написать текст поста для Инстаграма* компании @insli.ru',
#        '- скрининг-интервью_x000D_\n- техническое интервью_x000D_\n- оффер-митинг',
#        '1. Отклик в Карьерном трекере._x000D_\n2. Выполнение тестового задания._x000D_\n3. Скрининг резюме._x000D_\n4. Собеседование с HR._x000D_\n5. Возможно собеседование с генеральным директором.',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с HR. _x000D_\n3. Тестовое задание. _x000D_\n4. Возможно собеседование с генеральным директором.',
#        '1. Отклик в Карьерном трекере. _x000D_\n2. Выполнение тестового задания. _x000D_\n3. Скрининг резюме. _x000D_\n4. Собеседование с HR и тимлидом.',
#        '1. Скрининг резюме_x000D_\n2. Знакомство менеджеров студии с кандитат-ом/кой._x000D_\n3. Техническое собеседование.',
#        '1. Собеседование ЗУМ с руководителем направления. _x000D_\n2. Прохождение СБ, в том числе полиграф. _x000D_\n3. Очное собеседование.',
#        '1. Скрининг резюме. _x000D_\n2. Интервью с рекрутером. _x000D_\n3. Интервью с тимлидом.',
#        '1. Скрининг резюме _x000D_\n2. Звонок с фаундером - практические вопросы о ваших предложениях в области продвижения продукта и понимании кандидата',
#        '1) Первичный скрининг_x000D_\n2) Технический собес_x000D_\n3) Финал',
#        '1. Скрининг резюме _x000D_\n2. Общий звонок с командой и лидами команды',
#        '1. Скрининг резюме _x000D_\n2. Звонок с фаундером - техническое интервью',
#        '1. Скрининг резюме_x000D_\n2. Интервью с лидом команды и текущим ПМ  (1 час)_x000D_\n3. Финальное интервью по оставшимся вопросам (15-20 минут)',
#        '1. Телефонный скрининг._x000D_\n2. Интервью с Руководителем отдела. _x000D_\n3. Интервью с генеральным директором и  командой',
#        '- скрининг резюме_x000D_\n- тестовое задание _x000D_\n- собеседование',
#        '1. Скрининг резюме_x000D_\n2. Онлайн собеседование',
#        '1) Скрининг и тестовое задание (направляет рекрутер)_x000D_\n2) Интервью с HR и руководителем',
#        '1. Первый короткий тест (https://forms.gle/cHVfm5uQ5qSM3Lmq6)_x000D_\n2. Второй более углубленный тест (https://forms.gle/WsHW6nBT5yza5HzA8)_x000D_\nЕсли ваши ответы нас устраивают, то переходим к 3 этапу_x000D_\n3. Мини-интервью с ассистентом  _x000D_\n4 Собеседование с руководителем',
#        '1. Скрининг резюме _x000D_\n2. Звонок с СТО _x000D_\n3. Возможно Тестовое Задание',
#        '- скрининг_x000D_\n- собеседование_x000D_\n- техсобес',
#        '1. Заполнение Анкеты по ссылке: _x000D_\nhttps://forms.gle/HGHabRD6HfvBgdR27_x000D_\n2. Скрининг резюме_x000D_\n3. Интервью с командой;_x000D_\n4. Тестовое задание (будет доступно после интервью).',
#        '1. Заполнение Анкеты по ссылке: _x000D_\nhttps://forms.gle/2MjLX4EnSHGJzT6w6_x000D_\n2. Скрининг резюме;_x000D_\n3. Интервью с командой;',
#        'Интервью',
#        '1. Собеседование с HR_x000D_\n2. Тестовое задание_x000D_\n3. Финальное собеседование с руководителем крауд отдела',
#        '1. Интервью_x000D_\n2. Тестовое задание_x000D_\n3. Ревью тестового от нашего разработчика_x000D_\n4. Если положительное решение, вывод на стажировку',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с HR. _x000D_\n3. Собеседование с руководителем проекта и с заместителем генерального директора._x000D_\n4. Собеседование с генеральным директором.',
#        '1. Тестовое Задание _x000D_\n2. Скрининг резюме _x000D_\n3. Звонок с фаундером - практические вопросы о ваших предложениях в области продвижения продукта и понимании кандидата',
#        'Гайд по этапам отбора здесь:_x000D_\nhttps://woolly-textbook-531.notion.site/3857e125ba624659b7cfbc6991443b2d',
#        '1) Скрининг_x000D_\n2) Интервью с руководителем отдела тестирования',
#        '1. Отклик через Карьерный Трекер. _x000D_\n2. Отклик через форму заявки на сайте программы. _x000D_\n3. Возможно собеседование с куратором.',
#        '1. Скрининг резюме_x000D_\n2. Собеседование-звонок _x000D_\n3. Тестовое Задание (опционально)',
#        '1. Заполнение Анкеты по ссылке: _x000D_\n https://forms.gle/tauhwcwG96rFPAtaA_x000D_\n2. Скрининг резюме;_x000D_\n3. Интервью с командой;',
#        '1. Скрининг резюме. _x000D_\n2. Интервью с тимлидом_x000D_\n3. Интервью с командой',
#        '1. Скрининг резюме; _x000D_\n2. Тестовое задание;_x000D_\n3. Собеседование с HR-менеджером;_x000D_\n4. Собеседование с нанимающим менеджером.',
#        '1. Отклик в Карьерном трекере. _x000D_\n2. Выполнение тестового задания. _x000D_\n3. Скрининг резюме. _x000D_\n4. Техническое собеседование.',
#        '1. Отклик с тестовым заданием_x000D_\n2. Сопроводительное с ответом на вопрос "готовы ли выйти при успешной стажировке?"_x000D_\n3. Проверка тестового и резюме _x000D_\n4. Собеседование с ментором стажировки',
#        'Скрининг_x000D_\nИнтервью_x000D_\nТестовое задание',
#        'Скрининг_x000D_\nИнтервью_x000D_\nТестовое задание (возможно)',
#        '1)скрининг с HR, _x000D_\n2) тестовое задание_x000D_\n3)  тех.собес по результатам тестового',
#        '1. Скрининг резюме_x000D_\n2. Тестовое задание и тех.собес по результатам тестового',
#        'Скрининг _x000D_\nИнтервью',
#        '1) Интервью с руководителем проекта-стартапа_x000D_\n2) Интервью с основателем проекта-стартапа',
#        '1. Скрининг резюме _x000D_\n2. HR-интервью_x000D_\n3. Тестовое задание_x000D_\n4. Техническое интервью_x000D_\n5. Финальное интервью',
#        '1. Скрининг резюме_x000D_\n2. Звонок с HR',
#        'Скрининг_x000D_\nИнтервью',
#        'Заполнение формы, прикрепленной к вакансии_x000D_\nИнтервью с руководителем',
#        '1. Скрининг резюме_x000D_\n2. Выполнение тестового задания._x000D_\n3. Интервью с HR manager._x000D_\n4. Интервью с Lead.',
#        '1) Скрининг резюме и сопроводительного_x000D_\n2) Мотивационное собеседование_x000D_\n3) Техническое задание_x000D_\n4) Проверка тестового с командой',
#        '1) звонок с HR_x000D_\n2) встреча с руководителем отдела  и с лидом',
#        '1. Тестовое задание_x000D_\n2. Техническое собеседование (~1 час)',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с HR._x000D_\n3. Собеседование с head of Recruitment.',
#        '1. Скрининг портфолио._x000D_\n2. Возможно тестовое задание._x000D_\n3. Встреча с заказчиком.',
#        'Интервью с кандидатом онлайн, проверка знаний SQL путем решения задач в реальном времени',
#        '1. тестовое задание_x000D_\n2. видео встреча - собеседование',
#        '1. Скрининг резюме_x000D_\n2.  Интервью: CTO + HR и Руководитель проекта _x000D_\n3. Интервью с HR',
#        '1. Скрининг резюме _x000D_\n2. Интервью с HR_x000D_\n3. Интервью с руководителем _x000D_\n4. Тестовое Задание',
#        '1. Скрининг резюме_x000D_\n2. Тестовое задание _x000D_\n3. Созвон с HR',
#        '1. Просмотр резюме; _x000D_\n2. Собеседование с руководителем.',
#        '1. Просмотр резюме; _x000D_\n2. Встреча с HR-менеджером; _x000D_\n3. Тестовое задание на знание Excel; _x000D_\n4. Встреча с директором по продажам.',
#        'Для отклика на вакансию также необходимо заполнить внутреннюю анкету агентства - прикреплена по ссылке Тестового задания. _x000D_\nВ полне ответа на тестовое достаточно написать "Анкету заполнил (а)". _x000D_\n_x000D_\nВ этапы отбора входит: _x000D_\n- знакомство с тим-лидом, _x000D_\n- самопрезентация о кандидате,_x000D_\n- составление и презентация тестового коммерческого предложения (под руководством наставника), _x000D_\n- тестово-ознакомительная неделя для погружения во внутренние процессы.',
#        '1. Отклик в Карьерном Трекере. _x000D_\n2. Первичное собеседование._x000D_\n3. Тестовое задание._x000D_\n4. Собеседование с руководителем отдела',
#        '1. Скрининг резюме_x000D_\n2. Видео-собеседование',
#        'Скрининг (сопроводительное письмо обязательно) _x000D_\nТестовое_x000D_\nИнтервью',
#        '- скрининг резюме, с последующей оценкой _x000D_\n- первичное телефонное интервью_x000D_\n- видео встреча_x000D_\n- тестовое задание',
#        '- скрининг_x000D_\n- интервью',
#        '1. Просмотр резюме; _x000D_\n2. Тестовое задание; _x000D_\n3. Короткое интервью с нанимающим менеджером.',
#        '1. Просмотр резюме; _x000D_\n2. Тестовое задание (возможно); _x000D_\n3. Собеседование с руководителем.',
#        '1. Отклик в Карьерном трекере. _x000D_\n2. Выполнение тестового задания. _x000D_\n3. Оценка тестового и портфолио. _x000D_\n4. Собеседование с нанимающим менеджером.',
#        '1. Скрининг резюме._x000D_\n2. Тестовое задание. _x000D_\n3. Собеседование с техлидом.',
#        '1. Скрининг резюме _x000D_\n2. Созвон с HR',
#        '- скрининг резюме_x000D_\n- тестовое задание_x000D_\n- собеседование',
#        '1. Скрининг резюме _x000D_\n2. Тестовое Задание (высылается партнером)_x000D_\n3. Созвон с командой _x000D_\n4. Техническое интервью',
#        '1. Скрининг резюме_x000D_\n2. Собеседование с HR. _x000D_\n3. Собеседование с тимлидом.',
#        '1. Просмотр резюме;_x000D_\n2. Тестовое задание; _x000D_\n3. Собеседование с руководителем и фаундерами агентства; _x000D_\n4. Собеседование с командой; _x000D_\n5. Обучение-стажировка 2 недели (пре-оффер). _x000D_\n_x000D_\nСтажировка неоплачиваемая. Она необходима для того, чтобы понять, справится ли кандидат с предстоящими задачами. _x000D_\n_x000D_\n6. Оффер (после прохождения стажировки).',
#        '1. Просмотр резюме; _x000D_\n2. Первый этап собеседования с руководителем: тестовое задание;_x000D_\n3. Второй этап собеседования с руководителем: hard & soft skills',
#        '1. Отклик в Карьерном Трекере. _x000D_\n2. Скрининг реюзме. _x000D_\n3. Заполнение анкеты от работодателя._x000D_\n4. Тестовое задание. _x000D_\n5. Собеседование с HR/техническим директором.',
#        '1) Скрининг резюме _x000D_\n2) Звонок с контактным лицом _x000D_\n2) Прием на стажировку, длительностью 4 недели',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с рекрутером. _x000D_\n3. Возможна встреча с лидом HR. _x000D_\n4. Знакомство с HR в офисе. _x000D_\n5. Знакомство с Head recruitment в офисе.',
#        '1) Скрининг резюме _x000D_\n2) Звонок с контактным лицом _x000D_\n3) Прием на стажировку, длительностью 4 недели',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с нанимающим менеджером.',
#        '1. Скрининг резюме_x000D_\n2. Звонок с фаундерами',
#        '1. Просмотр резюме; _x000D_\n2. Собеседование с нанимающим менеджером; _x000D_\n3. Прохождение стажировки (1-2 мес). _x000D_\nФормат стажировки: кандидату будут давать задачи на реализацию и по итогам смотреть, как он с ними справился. Стажировка может закончиться раньше, в зависимости от результатов;_x000D_\n4. После того, как компания сможет убедиться в том, что сотрудник хорошо справляется с поставленными задачами и требуемой нагрузкой, с ним заключат договор на part-time.',
#        '1) К отклику приложить выполненное тестовое_x000D_\n2) Собеседование с Продактом по хард- и софт-скиллам',
#        '1) Выполнение тестового задания_x000D_\n2) Собеседование с Продактом по софт-скиллам',
#        '- скрининг резюме_x000D_\n- мотивационное (сопроводительное) письмо_x000D_\n- тестовое задание',
#        '1. Скрининг резюме_x000D_\n2. Звонок с HR _x000D_\n3. Финальное собеседование',
#        '1. Просмотр резюме; _x000D_\n2. Собеседование с нанимающим менеджером; _x000D_\n3. Тестовое задание.',
#        '1. Просмотр резюме; _x000D_\n2. Собеседование с нанимающим менеджером.',
#        'Мы не любители формальностей и затягивания процессов, к найму подходим также. Тебя ждет:_x000D_\n_x000D_\nТестовое задание, которое поможет нам понять твои навыки._x000D_\nСобеседование с потенциальными коллегами максимум на час, где мы поговорим про твой опыт и про наши задачи._x000D_\nФинальное интервью с руководителем отдела продаж, тимлидом и HR, где мы окончательно убедимся, что подходим друг другу._x000D_\n*Будем рады, если в сопроводительном письме расскажешь о том, насколько ты погружен(а) в спортивную повестку.',
#        '1. Скрининг резюме_x000D_\n2. Собеседование с нанимающим менеджером',
#        '1) скрининг резюме _x000D_\n2) личное интервью',
#        '1. Скрининг резюме _x000D_\n2. Созвон с HR_x000D_\n3. Тестовое Задание/техническое интервью',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с HR. _x000D_\n3. Возможно собеседование с техлидом.',
#        '1. Просмотр резюме; _x000D_\n2. Телефонное интервью с HR-менеджером; _x000D_\n3. Тестовое задание; _x000D_\n4. Финальное интервью._x000D_\n_x000D_\nНа данной позици предусмотрена неоплачиваемая стажировка (1 неделя). _x000D_\n_x000D_\nПо окончанию стажировки будет оплачиваемый тестовый месяц (продолжение обучения + практическая работа).',
#        '1. Скрининг резюме _x000D_\n2. Собеседование',
#        '1. Скрининг резюме_x000D_\n2. Звонок с фаундером и программистом',
#        '1. Скрининг резюме._x000D_\n2. Тестовое задание._x000D_\n3. Собеседование с нанимающим менеджером.',
#        '1. Просмотр резюме; _x000D_\n2. Собеседование-знакомство с командой. Каждая сторона рассказывает о себе. Кандидат проходит небольшое тестовое.',
#        '1. Скрининг резюме_x000D_\n2. Собеседование и проверка на простых задачах на одном из коммерческих проектов',
#        'Техническое собеседование.',
#        'Тестовое задание_x000D_\nСобеседование_x000D_\nТрудоустройство',
#        '1. Скрининг резюме. _x000D_\n2. Интервью с рекрутером. _x000D_\n3. Интервью с HR. _x000D_\n4. Самостоятельное изучение базы знаний. _x000D_\n5. Экзамен по базе знаний.',
#        '1. Просмотр резюме;_x000D_\n2. Собеседование с нанимающим менеджером; _x000D_\n2. При необходимости тестовое задание -  короткое, на оценку логики мышления.',
#        '1. Скрининг портфолио и резюме_x000D_\n2. Интервью-собеседование с главным дизайнером',
#        '1) Скрининг резюме _x000D_\n2) Собеседование_x000D_\n3) Тестовое задание',
#        '1. Скрининг резюме _x000D_\n2. Созвон-интервью_x000D_\n3. Финальное очное собеседование в офисе',
#        '1. Первичное собеседование с HR; _x000D_\n2. Интервью с руководителем подразделения; _x000D_\n3. Возможно тестовое задание',
#        '1. Скрининг резюме _x000D_\n2. Собеседование общее _x000D_\n3. Техническое интервью',
#        '1. Скрининг резюме. _x000D_\n2. Интервью с HR. _x000D_\n3. Собеседование с руководителем отдела. _x000D_\n4. Тестовый день.',
#        '1. Просмотр резюме; _x000D_\n2. Собеседование с нанимающим менеджером; _x000D_\n3. Собеседование с директором отдела маркетинг.',
#        '1. Скрининг резюме. _x000D_\n2. Встреча с командой.',
#        '1. Скрининг резюме _x000D_\n2. Собеседование с фаундером',
#        '1. Отклик в Трекере. _x000D_\n2. Выполнение тестового задания. _x000D_\n3. Скрининг резюме. _x000D_\n4. Собеседование с руководителем отдела.',
#        '1. Скрининг резюме и портфолио_x000D_\n2. Созвон с фаундером',
#        '1. Просмотр резюме; _x000D_\n2. Техническое интервью с лайвкодингом;_x000D_\n3. Тестовое задание (опционально);_x000D_\n4. Повторное очное интервью;_x000D_\n5. Проверка Службы безопасности.',
#        'Планируется два этапа: _x000D_\nпервая встреча с hr и финальная с руководителем отдела',
#        '1, Скрининг резюме _x000D_\n2. Созвон с командой',
#        '1. Скрининг резюме _x000D_\n2. Тестовое задание _x000D_\n3. Собеседование',
#        'Скрининг резюме и портфолио_x000D_\nИнтервью с командой',
#        '1. скрининг_x000D_\n2. тестовое задание_x000D_\n3. интервью',
#        'Собеседование, возможно тестовое задание',
#        '1. Скрининг резюме. _x000D_\n2. Тестовое задание. _x000D_\n3. Собеседование с тимлидом',
#        'Собеседование с руководителем',
#        '1. Скрининг резюме._x000D_\n2. Онлайн - интервью с Team Lead IT-recruiter',
#        'Тестовое_x000D_\nИнтервью',
#        '1. Отклик в Карьерном трекере. _x000D_\n2. Выполнение тестового задания. _x000D_\n3. Скрининг резюме и проверка тестового задания._x000D_\n4. Собеседование с нанимающим менеджером.',
#        'тестовое_x000D_\nинтервью',
#        '1. Скрининг _x000D_\n2. Интервью с нанимающем менеджером _x000D_\n3. Возможно тестовое задание',
#        '1. Отклик в трекере _x000D_\n2. Заполнение анкеты Antipoff Group - https://b24-6n8vgw.bitrix24.site/crm_form7/ (ОБЯЗАТЕЛЬНЫЙ ЭТАП)',
#        '1. Просмотр резюме; _x000D_\n2. Собеседование с HR;_x000D_\n3. Техническое задание;_x000D_\n3. Техническое интервью с нанимающим менеджером._x000D_\n_x000D_\n2 и 3 этап собеседования может меняться местами.',
#        '1. Скрининг резюме _x000D_\n2. Созвон с фаундером',
#        '1. Телефонное интервью с HR 2. Онлайн встреча с руководителем отдела 3. ТЗ-по результатам 2 этапа',
#        'Скрининг резюме и сопроводительного _x000D_\nСобеседование',
#        '1. Скрининг_x000D_\n2. Техническое интервью_x000D_\n3. Собеседование общее',
#        '1. Скрининг резюме _x000D_\n2. Собеседование с HR',
#        '1. Скрининг резюме _x000D_\n2. Очное собеседование в офисе компании',
#        '- прохождение теста (онлайн)_x000D_\nСрок выполнения - 2 рабочих дня._x000D_\n_x000D_\n- короткое интервью (онлайн)_x000D_\n- тестовое задание (удаленно)',
#        '1. Отклик на лендинге - https://yandex.ru/yaintern/analyst_intern?utm_source=practicum&utm_medium=chat&utm_campaign=ads_analysts_x000D_\n_x000D_\n_x000D_\n2. Решение тестового задания_x000D_\n3. Интервью_x000D_\n4. Выход на стажировку - 20 июня',
#        '1. Тестовое Задание_x000D_\n2. Рассмотрение тест-кейсов, решённых кандидатом. _x000D_\n3. Собеседование',
#        '1. Просмотр резюме и тестового задания; _x000D_\n2. Собеседование с нанимающим менеджером.',
#        '1) ТЗ_x000D_\n2) HR интервью_x000D_\n3) Тех. интервью',
#        '1. Отбор по резюме;_x000D_\n2. Интервью;_x000D_\n3. Тестовое задание.',
#        '1. Тестовое Задание _x000D_\nСрок выполнения - неделя _x000D_\nРешенное тестовое задание нужно прислать на почту: a.belova@elama.ru_x000D_\nВ письме должно быть указано примерное время потраченное на работу над заданием. _x000D_\n_x000D_\nМы ожидаем получить следующие файлы:_x000D_\n1. Файл с отчетом (расширение pbix), _x000D_\n2. Файл с кодом на SQL (расширение sql или txt),_x000D_\n3. Опционально файл с кодом Python (py или ipynb)._x000D_\n_x000D_\n2. Собеседование',
#        '1. Просмотр резюме; _x000D_\n2. Собеседование с HR-менеджером; _x000D_\n3. Собеседование с Founder компании.',
#        '1. Тестовое задание _x000D_\nПо ссылке для вас. Срок выполнения - неделя _x000D_\n2. Созвон с командой',
#        '1. Скрининг резюме _x000D_\n2. Первичное собеседование_x000D_\n3. Выполнение тестового задания',
#        '1.Скрининг резюме  _x000D_\n2. Общение с рекрутером. _x000D_\n3. Технические собеседование._x000D_\n4. Встреча с руководителем.',
#        '1. Скрининг резюме _x000D_\n2. Созвон с основателем',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с HR. _x000D_\n3. Тестовое задание (по вакансии: https://hh.ru/vacancy/79728732). _x000D_\n4. Собеседование с нанимающим менеджером.',
#        '1. Скрининг резюме _x000D_\n2. Звонок-знакомство с фаундером',
#        '1. Скрининг резюме _x000D_\n2. Собеседование с лид разработчиком и руководителем проекта',
#        '1.  Тест на знание основной задачи - поиска кандидатов_x000D_\n2.  Собеседование',
#        '1. Скрининг резюме _x000D_\n2. Созвон с HR _x000D_\n3, Техническое интервью',
#        '- Написание тестового задания _x000D_\n- После проверки тестового задания, если кандидат справился хорошо, мы приглашаем его пройти техническое собеседование _x000D_\n- После успешного собеседования кандидата принимают на работу, с ним проходит онбординг в компании для адаптации',
#        'Отбор CV тим лидом _x000D_\nИнтервью с HR_x000D_\nТестовое _x000D_\nИнтервью с Тим лидом _x000D_\nИнтервью с СЕО и СТО',
#        '- скрининг,_x000D_\n- тестовое задание,_x000D_\n- собеседование',
#        '1. Просмотр интервью;_x000D_\n2. Собеседование с нанимающим менеджером;_x000D_\n2. Тестовое задание (опционально).',
#        '1. Ознакомление с резюме, сопроводительным письмом и портфолио._x000D_\n2. Общий созвон с проджектом и тимлидом фронтенд-разработки.',
#        '1. Скрининг резюме _x000D_\n2. Звонок с HR',
#        '1. Просмотр резюме; _x000D_\n2. Собеседование с нанимающим менеджером; _x000D_\n3. Тестовое задание (возможно),',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с HR. _x000D_\n3. Собеседование с нанимающим менеджером. _x000D_\n4. Возможно тестовое задание.',
#        '1. Скрининг резюме_x000D_\n2. Тестовое задание: короткое и комплексное _x000D_\n3. Тестовые дни в офисе (оплачиваемые)',
#        'Скрининг резюме и портфолио_x000D_\nИнтервью онлайн',
#        'Перед откликом необходимо заполнить анкету, чтобы компания могла внести данные в свою систему Bitrix: https://docs.google.com/forms/d/1npKr_NtEHMTGWPUIGPzuhCChQ_e92nOVIDItRZEagTs/viewform?edit_requested=true _x000D_\n_x000D_\nЭтап 1. Просмотр резюме и тестового задания; _x000D_\nЭтап 2. Собеседование с HR-менеджером; _x000D_\nЭтап 3: Собеседование с нанимающим менеджером.',
#        'Перед откликом необходимо заполнить анкету, чтобы компания могла внести данные в свою систему Bitrix: https://docs.google.com/forms/d/1uIOctmSgD2ue-tVFacZEg7HB0qJu-6Ns45zfvBmDKCM/viewform?edit_requested=true _x000D_\n_x000D_\nЭтап 1. Просмотр резюме и тестового задания; _x000D_\nЭтап 2. Собеседование с HR-менеджером; _x000D_\nЭтап 3: Собеседование с нанимающим менеджером.',
#        '1. Скрининг резюме _x000D_\n2. Звонок с HR и руководством',
#        '1. Просмотр резюме;_x000D_\n2. Выполнение тестового задания (возможно);  _x000D_\n3. Собеседование с HR-менеджером; _x000D_\n4. Собеседование с нанимающим менеджером.',
#        '1. Скрининг резюме _x000D_\n2. Интервью с HR и Лидом _x000D_\n3. Встреча в офисе',
#        '1. Скрининг_x000D_\n2. Интервью_x000D_\n3. Тестовое',
#        'Скрининг_x000D_\nТестовое задание_x000D_\nИнтервью',
#        'Первичный звонок с HR;_x000D_\nИнтервью, которое проводит лид команды IT рекрутинга;_x000D_\nФинальное интервью с руководителем Talent acquisition или CHRO.',
#        '1. Скрининг резюме. _x000D_\n2. Участие в установочном вебинаре.',
#        '1. Скрининг резюме_x000D_\n2. Тестовое задание _x000D_\n3. Собеседование',
#        '- Скрининг резюме (возможны правки по комментариям карьерного консультанта-менеджера трудоустройства)_x000D_\n- Заполнение анкеты _x000D_\n- Собеседование',
#        '- Скрининг резюме (возможна доработка по комментариям карьерного консультанта-менеджера трудоустройства)_x000D_\n- Заполнение анкеты_x000D_\n- Собеседование',
#        'Собеседование с фаундером',
#        '1. Просмотр резюме; _x000D_\n2. Собеседование онлайн; _x000D_\n3. Собеседование в офисе (опционально).',
#        '- Скрининг с проверкой на наличие анкеты https://forms.gle/1DHmk8BHmi8Wugz29_x000D_\n- Собеседование',
#        '1. Скрининг резюме / Оценка портфолио_x000D_\n2. Выполнение тестового задания_x000D_\n3. Защита тестового задания и собеседование_x000D_\n4. Оффер',
#        'Интервью_x000D_\n_x000D_\nРассматриваем отклики только с сопроводительным письмом',
#        'Техническое интервью_x000D_\nИнтервью с командой',
#        '1. Просмотр резюме; _x000D_\n2. Звонок с HR-менеджером; _x000D_\n3. Тестовое задание (возможно); _x000D_\n4. Собеседование с нанимающим менеджером.',
#        'Просмотр портфолио_x000D_\nИнтервью',
#        '1 этап -телефонное предварительное интервью с рекрутером_x000D_\n2 этап - техническое собеседование с руководителем и направление тестового задания',
#        '1. Отклик в Карьерном трекере. _x000D_\n2. Выполнение тестового задания. _x000D_\n3. Скрининг резюме и тестового задания. _x000D_\n4. Собеседование с рекрутером. _x000D_\n5. Собеседование с HR._x000D_\n6. Тестовый день работы в компании для оценки кандидата в бою. В случае удовлетворительном оценки день оплачивается и кандидат остается. В случае неудовлетворительной оценки тестовый день не оплачивается',
#        '1. Скрининг резюме _x000D_\n2. Небольшое тестовое задание _x000D_\n3. Финальный созвон',
#        '1. Скрининг резюме_x000D_\n2. Звонок с командой',
#        '1. Просмотр резюме и тестового задания; _x000D_\n2. Знакомство с HR-менеджером; _x000D_\n3. Знакомство с командой.',
#        '1. Просмотр резюме и тестового задания; _x000D_\n2. Собеседование с CEO компании.',
#        '- Скрининг резюме_x000D_\n- Тестовое_x000D_\n- Собеседование',
#        '1. Скрининг резюме _x000D_\n2. Звонок с HR и CTO',
#        '1. Отклик в Карьерном Трекере. _x000D_\n2. Заполнение формы работодателя. _x000D_\n3. Первичное собеседование._x000D_\n4. Тестовое задание._x000D_\n5. Собеседование с руководителем отдела',
#        'Тестовое на софт-скиллс, тестовое по верстке',
#        '1) Тестовое задание (прикреплено к вакансии)_x000D_\n2) Интервью',
#        '1.Первичное знакомство и сбор информации о человеке ( HR )_x000D_\n2. Техническое собеседование_x000D_\n3. Стажировка в пет проекте',
#        'Интервью с СЕО',
#        'Отдаем предпочтение выходцам из других креативных агентств_x000D_\nМы посмотрим на твой отклик и пригласим на собеседование_x000D_\nПообщаемся с тобой вместе с Арт-директором_x000D_\nДадим тестовое задание_x000D_\nИ если у нас будет мэтч - вышлем оффер.',
#        '1. Обязательно! Заполнение анкеты от работодателя - https://b24-6n8vgw.bitrix24.site/crm_form7/_x000D_\n_x000D_\n⚠️В поле онлайн анкеты “Расскажите о себе”, укажи какими технологиями из стека владеешь._x000D_\n_x000D_\n2. Собеседование',
#        'Этапы отбора такие определяют:_x000D_\n1️⃣подача заявки_x000D_\nhttps://first.rt.ru/?utm_source=fut&utm_medium=partners&utm_campaign=practicumit&utm_content=al_x000D_\n_x000D_\n2️⃣онлайн-тестирование_x000D_\n3️⃣телефонное интервью_x000D_\n4️⃣собеседование',
#        '1. Просмотр резюме; _x000D_\n2. Тестовое задание; _x000D_\n3. Собеседование по ВКС.',
#        '1. Просмотр резюме; _x000D_\n2. Тестовое задание (возможно); _x000D_\n3. Собеседование с HR;_x000D_\n4. Техническое собеседование. _x000D_\n_x000D_\nВозможно, какие-то этапы будут пропускаться.',
#        '1. Скрининг резюме_x000D_\n2. Тестовое задание + личное собеседование_x000D_\n3. Стажировка_x000D_\n4. Офер по результатам успешной стажировки',
# ...
#        '1. Скрининг_x000D_\n2. Интервью с руководителем (общая и техническая часть)_x000D_\n3. Возможна дополнительное интервью',
#        'тестовое задание_x000D_\nинтервью',
#        'интервью_x000D_\nвозможно тестовое задание',
#        '1. Скрининг портфолио _x000D_\n2. Тестовое Задание _x000D_\n3. Собеседование',
#        '1. Скрининг резюме_x000D_\n2. Тестовое Задание (опцион)_x000D_\n3. Собеседование',
#        '- Скрининг резюме _x000D_\n- Тестовое задание _x000D_\n- Собеседование',
#        '1. Отбор резюме._x000D_\n2. Онлайн собеседование._x000D_\n3. Для тех кто в Москве и Ообласти желательно: встреча в офисе.',
#        '1. Отклик на сайте партнера _x000D_\nhttps://rabota.leroymerlin.ru/vacancies/64b1129d78d0420024a84906?utm_source=Ya_Practicum&utm_medium=digital_media_display&utm_content=Vacancy_System_analyst_&utm_campaign=Ya_Practicum_x000D_\n_x000D_\n2. Собеседование _x000D_\n3. Тестовое Задание (опцион)',
#        '1. Отклик на сайте партнера _x000D_\nhttps://rabota.leroymerlin.ru/vacancies/6524f9a7ac7aec0023eabf7e?utm_source=Ya_Practicum&utm_medium=digital_media_display&utm_content=Vacancy_Data_analyst_&utm_campaign=Ya_Practicum_x000D_\n_x000D_\n2. Собеседование _x000D_\n3. Тестовое Задание (опцион)',
#        '- скрининг резюме_x000D_\n- собеседование _x000D_\n- тестовое при необходимости',
#        'ВАЖНО: для отклика обязательно заполнение анкеты - https://forms.yandex.ru/surveys/13004282.6e6e55e9f986641230139cb5ab83becee8b4082f/?utm_source=practicum',
#        '1. Скрининг резюме _x000D_\n2. Встреча online - команда задаст технические вопросы на понимание языка _x000D_\n3. Финальная встреча',
#        '1. Скрининг резюме _x000D_\n2. Собеседование _x000D_\n3. Тестовый день в офисе - нужно будет сделать тестовое задание',
#        '1. Заполнение формы на сайте:_x000D_\nhttps://forms.yandex.ru/surveys/13467459.399316410d0f50bd99dec59995e96b582b72115e/_x000D_\n_x000D_\n2. Тестовое Задание _x000D_\n3. Собеседование',
#        '1. Отклик в Трекере. _x000D_\n2. Скрининг резюме. _x000D_\n3. Собеседование с командой. _x000D_\n4. Тестовое задание (готовится под всех индивидуально)',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с HR. _x000D_\n3. Собеседование с нанимающим менеджером (на собеседовании будет тестовые задания на проверку аналитических способностей)',
#        '1. Отклик в Трекере. _x000D_\n2. Скрининг резюме. _x000D_\n3. Тестовое задание. _x000D_\n4. Собеседование с рекрутером. _x000D_\n5. Тестовое задание в офисе+итоговое собеседование.',
#        '1. Скрининг _x000D_\n2. Собеседование_x000D_\n3. Возможно тестовое задание',
#        '1. Скрининг_x000D_\n2. Собеседование/тестовое',
#        '1. Скрининг резюме. _x000D_\n2. Интервью с HR. _x000D_\n3. Интервью с нанимающим менеджером.',
#        '1. Выполнение тестового задания. _x000D_\n2. Отклик в Карьерном Трекере_x000D_\n3. Скрининг резюме. _x000D_\n4. Собеседование с руководителем отдела.',
#        '1. Скрининг резюме_x000D_\n2. Тестовое задание_x000D_\n3. Итоговое собеседование',
#        'Интервью_x000D_\nЕсли тебя заинтересовала наша вакансия, пожалуйста, расскажи о своем самом большом профессиональном достижении в сопроводительном письме. Отклики без сопроводительного письма не будут рассмотрены, поскольку мы считаем, что самые крутые ребята всегда его пишут, а других мы не рассматриваем.',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с HR. _x000D_\n3. Собеседование с нанимающим менеджером + тестовое задание',
#        'Тестовое задание (прикреплено)_x000D_\nИнтервью',
#        'Порядок обсуждения совместной работы:_x000D_\n_x000D_\n— Ты присылаешь нам своё резюме и примеры готовых и развернутых проектов, можно развернуть пет-проекты, можно тестовые. Если ещё не разворачивали проекты на домен, можно воспользоваться: netlify, vercel.app_x000D_\n_x000D_\n— Мы в течение 2-3х дней возвращаемся к тебе с обратной связью_x000D_\n_x000D_\n— Даём тестовое_x000D_\n_x000D_\n— Приглашаем на собеседование_x000D_\n_x000D_\n— Первой строчкой в отклике пиши — "мне подходит попроектная занятость"',
#        '1. Просмотр резюме; _x000D_\n2. Онлайн знакомство с непосредственным руководителем; _x000D_\n3. Тестовое задание на SQL;  _x000D_\n4. Техническое интервью с нашим аналитиком;_x000D_\n5. Очная встреча с непосредственным руководителем. _x000D_\n_x000D_\nЭтапы могут варьироваться.',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с рекрутером. _x000D_\n3. Собеседование с нанимающим менеджером. _x000D_\n4. Возможно тестовое задание.',
#        '1. Просмотр резюме; _x000D_\n2. Собеседование с HR, общее вводное, куда входит выполнение тестового задания; _x000D_\n3. Собеседование с тимлидом/руководителем направления; _x000D_\n4. Собеседование с руководителем отдела.',
#        '1. Скрининг резюме_x000D_\n2. Собеседование _x000D_\n3. Прохождение полиграфа',
#        '1. Скрининг портфолио и резюме _x000D_\n2. В зависимости от портфолио возможно тестовое задание _x000D_\n3. Собеседование',
#        '1. Скрининг резюме_x000D_\n2. Собеседование с фаундером',
#        'Собеседование_x000D_\nНа собеседовании быть готовым к лайв кодингу (чистый JavaScript)._x000D_\nЕсли есть примеры реализованных проектов или примеры написания кода, прикрепить их к сопроводительному письму.',
#        'Интервью_x000D_\nКейсы (портфолио) по контенту приветствуются.',
#        '1. Заявка на сайте партнера _x000D_\nhttps://moscowcareer.mguu.ru/itgorod/?utm_source=yp&utm_medium=article&utm_campaign=itinterns_invite_x000D_\n_x000D_\n2. Онлайн-тестирование_x000D_\n3. Очный этап отбора_x000D_\n4. Знакомство с руководителем_x000D_\n5. Подписание договора',
#        '1. Скрининг резюме _x000D_\n2. Собеседование_x000D_\n3. Стажировочная неделя.',
#        '1. Скрининг портфолио и резюме _x000D_\n2. Собеседование _x000D_\n3. Тестовое Задание',
#        '3 этапа. HR интервью, тестовое задание и интервью с руководителем',
#        '1. Скрининг резюме_x000D_\n2. Тестовое Задание _x000D_\nВажный момент по тестовому заданию. Планируй от 4 часов на его выполнение. Тестовое задание оплачивается после того как решим работать вместе._x000D_\n_x000D_\n3. Собеседование',
#        '1. Скрининг резюме _x000D_\n2. Собеседование с лидом команды _x000D_\n3. Административное собеседование с HR',
#        '1. Отклик в Карьерном Трекере и сообщение нанимающему менеджеру в Телеграм: @dm_goodman - Дмитрий_x000D_\n2. Скрининг резюме. _x000D_\n3. Тестовое задание. _x000D_\n4. Собеседование с нанимающим менеджером.',
#        '1. Просмотр резюме; _x000D_\n2. Интервью в два этапа.',
#        '1. Выполнение тестового задания. _x000D_\n2. Отклик в Карьерном Трекере. _x000D_\n3. Скрининг резюме и проверка тестового задания. _x000D_\n4. Собеседование с HR. _x000D_\n5. Собеседование с нанимающим менеджером.',
#        '1. Заявка на сайте партнера_x000D_\nСсылка: https://consultant.fut.ru/product-manager/?utm_source=partners&utm_medium=practicum_x000D_\n_x000D_\n2. Отбор партнером - собеседование/тестовое задание',
#        '1. Тестовое по ссылке_x000D_\nhttps://crezu.notion.site/QA-cd4a7e0563a3412cbb16029c90b2fa87_x000D_\n2. Собеседование',
#        '- пройти тестирование (более 80% правильных ответов)_x000D_\n- собеседование',
#        '1. Скрининг резюме_x000D_\n2. Собеседование _x000D_\n3. Тестовое Задание (опцион)',
#        '1. Скрининг резюме _x000D_\n2. Собеседование _x000D_\n3. Стажировка',
#        '1. Просмотр резюме;_x000D_\n2. Интервью с HR-менеджером (≈ 10-20 мин); _x000D_\n3. Интервью с нанимающим менеджером (≈ 30-40 мин); _x000D_\n4. Тестовое задание.',
#        '1. Скрининг резюме и сопроводительного _x000D_\n2. Собеседование со руководителем проектного офиса – познакомишься с руководителем команды, обсудим конкретные проекты и задачи._x000D_\n3. Тестовое задание._x000D_\n4. Собеседование с исполнительным директором – обсуждаем финансовую грамотность и экономику проекта._x000D_\n5. Принимаем решение насколько мы подходим друг другу._x000D_\n6. Делаем оффер и назначаем дату старта совместного пути.',
#        '1. Выполнение тестового задания. _x000D_\n2. Отклик в Карьерном Трекере. _x000D_\n3. Собеседование с HR. _x000D_\n4. Собеседование с нанимающим менеджером. _x000D_\n5. Тестовое задание.',
#        '1) Выполнение тестового задания_x000D_\n2) Техническое интервью_x000D_\n3) Проверка СБ',
#        '1. Оценка портфолио и резюме. Прикрепляйте, пожалуйста, ссылку на портфолио._x000D_\n2. Собеседование',
#        '1. Отклик_x000D_\n2. Тестовое задание _x000D_\n3. Собеседование._x000D_\n_x000D_\nДля участия в отборе напиши, пожалуйста, напрямую @InTimeDigitizeMeToLive120 чётко по плану:_x000D_\n_x000D_\n1. Резюме_x000D_\n2. Текущие прикладные навыки и стек_x000D_\n3. Дополнительные скиллы и ссылку на проект_x000D_\n4. Готовность к выполнению тестового_x000D_\n5. Название вакансии',
#        '1. Скрининг резюме. _x000D_\n2. Интервью с нанимающим менеджером.',
#        '1. Скрининг резюме _x000D_\n2. Онлайн собеседование _x000D_\n3. Проверка СБ _x000D_\n4. Очное собеседование с СБ',
#        '1. Скрининг резюме. _x000D_\n2. Короткое интервью с рекрутером. _x000D_\n3. Собеседование с HR. _x000D_\n4. Тестовое задание. _x000D_\n5. Собеседование с нанимающим менеджером.',
#        '1. Просмотр резюме; _x000D_\n2. Интервью с руководителем проекта; _x000D_\n3. Техническое интервью; _x000D_\n5. Интервью с генеральным директором; _x000D_\n6. Оффер и подписание договора.',
#        '1. Заявка на сайте партнера _x000D_\nСсылка: https://fut.ru/programs/mvideo-eldorado-it/?utm_source=mtech&utm_medium=partners&utm_campaign=practicum&utm_content=all _x000D_\n_x000D_\n2. Телефонное интервью_x000D_\n3. Тестовое задание_x000D_\n4. Собеседование',
#        '1. Просмотр резюме; _x000D_\n2. Тестовое задание; _x000D_\n3. Собеседование с нанимающим менеджером. _x000D_\nВажно: 2 и 3 этап могут меняться местами.',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с нанимающим менеджером',
#        '1. Скрининг резюме _x000D_\n2. Собеседование _x000D_\n3. Тестовое Задание (опицон)',
#        '1. Скрининг резюме._x000D_\n2. Телефонное собеседование._x000D_\n3. Собеседование с Техническим Директором. Здесь могут быть задачки.',
#        '1. Просмотр резюме; _x000D_\n2. Тестовое задание; _x000D_\n3. Собеседование с продакт менеджером; _x000D_\n4. Собеседование с СЕО. _x000D_\n_x000D_\nВажно: проджекту не нужно будет разрабатывать тест-кейсы на этой вакансии. Тестовым заданием проверяют внимательность, способность систематично и логично излагать свои мысли.',
#        '- скрининг резюме_x000D_\n- небольшое тестовое _x000D_\n- собеседование с собственницей',
#        '1. Скрининг _x000D_\n2. Собеседование с нанимающим менеджером',
#        '1. Тестовое Задание _x000D_\n2. Собеседование',
#        '2 этапа, дистанционный формат в GoogleMeet:_x000D_\n1 интервью (1 час) с будущим руководителем, обсуждение проекта/задач + техническая часть_x000D_\n2 интервью (30 мин) финальное, знакомство с руководителем управления',
#        '1. Скрининг портфолио и резюме _x000D_\n2. Собеседование_x000D_\n3. Тестовое/ тестовая неделя_x000D_\n_x000D_\nИ после этого как раз определяемся с дальнейший трудоустройством',
#        'Скрининг Интервью + тестовое задание',
#        '1. Выполнение тестового задания _x000D_\nВзять его можно по ссылке: https://edu.sirius.online/jobs/projectmanager_x000D_\n_x000D_\n2. Скрининг резюме, сопроводительного и тестового задания _x000D_\n3. Интервью',
#        'Этапы отбора:_x000D_\n1. Просмотр резюме; _x000D_\n2. Техническое собеседование; _x000D_\n3. Возможно тестовое задание.',
#        '1. Скрининг резюме _x000D_\n2. Техническое собеседование_x000D_\n3. Финальное собеседование с руководителем',
#        'Скрининг резюме _x000D_\nСобеседование с HR_x000D_\nТестовое задание_x000D_\nСобеседование с руководством',
#        '1. Скрининг резюме _x000D_\n2. Звонок-знакомство. _x000D_\n3. Тестовое Задание_x000D_\n4. Финальный звонок (опционально)',
#        '1. Если ты решил откликнуться на вакансию, то ответь, пожалуйста, на несколько вопросов в анкете — это поможет нам лучше понять, насколько ты подходишь на эту позицию. Постарайся быть максимально честным, тогда в случае несовпадения — мы не потратим оба слишком много времени, чтобы это осознать. _x000D_\n_x000D_\nАнкета для отклика на вакансию: https://forms.gle/mwJZnnYjyHt275zW9_x000D_\n_x000D_\n2. Собеседование',
#        '1. Скрининг резюме _x000D_\n2. Собеседование техническое небольшое _x000D_\n3. Подписание NDA _x000D_\n4. Испытательная неделя',
#        '1. Скрининг резюме _x000D_\n2. Техническое собеседование небольшое _x000D_\n3. Подписание NDA_x000D_\n4. Тестовая неделя',
#        '1. Просмотр резюме; _x000D_\n2. Оплачиваемое тестовое задание; _x000D_\n3. Собеседование; _x000D_\n4. Оффер.',
#        '1. Скрининг резюме (заявок)_x000D_\n2. Собеседование _x000D_\n3. Тестовое Задание (опционально)',
#        '1. Скрининг резюме _x000D_\n2. Онлайн-собеседование',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с тимлидом QA_x000D_\n3. Собеседование с руководителями компании',
#        '1. Скрининг резюме _x000D_\n2. Анкета_x000D_\n3. Интервью',
#        '1. Скрининг резюме _x000D_\n2. Тестовое Задание (опцион)_x000D_\n3. Собеседование',
#        '1. Скрининг резюме _x000D_\n2. Техническое интервью_x000D_\n3. Тестовое Задание',
#        '- скрининг резюме_x000D_\n- тестирование (более 80% правильных ответов)_x000D_\n- собеседование_x000D_\n_x000D_\nТестового задания нет!',
#        '1. Просмотр резюме; _x000D_\n2. Приглашение на собеседование; _x000D_\n3. Оффер.',
#        '1. Отклик в Трекере. _x000D_\n2. Скрининг резюме и заполнение входной анкеты. _x000D_\n3. Два зум-собеседования с HR и нанимающим менеджером. _x000D_\n4. Собеседование в офисе.',
#        '1. Скрининг резюме. _x000D_\n2. Собеседование с HR. _x000D_\n3. Собеседование с нанимающим менеджером',
#        '1. Скрининг резюме._x000D_\n2. Тестовое задание._x000D_\n3. Интервью с нанимающим менеджером._x000D_\n3. Интервью с директором.',
#        '1. Скрининг резюме _x000D_\n2. Собеседование _x000D_\n3. Тестовое Задание (опционально)_x000D_\n4. Финальное собеседование _x000D_\n5. Проверка СБ',
#        '1. Тестовое Задание_x000D_\nhttps://disk.yandex.ru/i/e_wLZ1I_drdGtg_x000D_\n_x000D_\n2. Скрининг резюме _x000D_\n3. Собеседование',
#        '1. Interview in Russian _x000D_\n2. Assessment Task_x000D_\n3. Final Interview in English',
#        '1. Скрининг резюме _x000D_\n2. Звонок-брифинг _x000D_\n3. Старт работы над задачей',
#        '1. Просмотр резюме; _x000D_\n2. Собеседование с нанимающим менеджером; _x000D_\n3. Собеседование с руководителем проектов.',
#        '1. Тестовое Задание _x000D_\nС ним можно ознакомиться по ссылке:_x000D_\nhttps://docs.google.com/document/d/1wQFKz8NkzuntPVF4647pmKbF3uzEYCFLLZR9spsavf0/edit?usp=sharing_x000D_\n_x000D_\n2. Техническое интервью_x000D_\n3. Общее собеседование',
#        '1. Скрининг резюме _x000D_\n2. Групповое собеседование  _x000D_\n3. Тестирование_x000D_\n4. Финальное собеседование',
#        '1. Анкета и отклик в трекере _x000D_\nhttps://forms.gle/oA5wCYPBGSL5voLU8_x000D_\n_x000D_\n2. Тестовое Задание _x000D_\nhttps://forms.gle/13NV7bbT5iBPNPkN8_x000D_\n_x000D_\n3. Собеседование',
#        '1. Тестовое Задание _x000D_\nhttps://disk.yandex.ru/i/e_wLZ1I_drdGtg_x000D_\n_x000D_\n2. Скрининг резюме и тестового _x000D_\n3. Собеседование',
#        '1. Скрининг резюме _x000D_\n2. Собеседование с командой _x000D_\n3. Тестовое Задание (опционально)',
#        '1.  Скрининг резюме _x000D_\n2. Первичное собеседование с HR_x000D_\n3. Тестовое задание_x000D_\n4. Встреча с тимлидом (тех.собес)',
#        '1. Просмотр резюме; _x000D_\n2. Собеседование с HR, техническим и генеральным директором;  _x000D_\n3. Тестовое задание ≈ 2 часа в удобное для кандидата время; _x000D_\n4. Оффер.',
#        '1. Скрининг резюме и портфолио_x000D_\n2. Тестовое задание_x000D_\n3. Собеседование',
#        '1. Анкета на сайте партнера + отклик в трекере  _x000D_\nСсылка: https://b24-6n8vgw.bitrix24.site/crm_form7/_x000D_\n_x000D_\n2. Скрининг резюме _x000D_\n3. Собеседование',
#        '1. Скрининг резюме_x000D_\n2. Личное собеседование_x000D_\n3. Тестовое Задание'],
#       dtype=object)

# %%
df['select_stages'] = df['select_stages'].astype(str).apply(openpyxl.utils.escape.unescape)
df['select_stages'] = df['select_stages'].str.replace('\n',',')
df['select_stages'] = df['select_stages'].str.replace('\r','')

# %%
df.select_stages.value_counts().head(20)
# Out:
# 1. Скрининг резюме ,2. Собеседование                                       85
# Интервью                                                                   33
# 1. Скрининг резюме,2. Собеседование                                        24
# 1. Просмотр резюме; ,2. Собеседование с нанимающим менеджером.             19
# 1. Скрининг резюме ,2. Собеседование ,3. Тестовое Задание (опцион)         18
# 1. Скрининг резюме ,2. Тестовое Задание ,3. Собеседование                  12
# Скрининг,Интервью                                                          12
# 1. Скрининг резюме ,2. Собеседование ,3. Тестовое Задание                  10
# Тестовое задание,Интервью                                                   8
# 1. Скрининг резюме ,2. Собеседование с фаундером                            8
# - скрининг резюме,- тестовое задание ,- собеседование                       7
# 1. Скрининг резюме ,2. Собеседование ,3. Тестовое Задание (опционально)     7
# 1. Скрининг резюме ,2. Звонок с командой                                    6
# - скрининг резюме,- собеседование,- возможно тестовое                       6
# 1. Скрининг резюме ,2. Техническое интервью                                 6
# Интервью,Тестовое задание                                                   6
# Скрининг,Тестовое задание,Интервью                                          5
# Интервью с командой                                                         5
# - скрининг резюме,- собеседование                                           5
# 1. Скрининг резюме,2. Звонок с HR ,3. Финальное собеседование               5
# Name: select_stages, dtype: int64

# %% [markdown]
# На данном этапе уже можно сказать, что скрининг резюме и собеседование являются базовыми этапами. указанными в вакансиях.

# %%
def clean_text(text):
    # Удаляем все символы, кроме букв и пробелов
    text = re.sub(r'[^а-яА-ЯёЁ\s]', '', text)
    # Преобразуем все буквы в нижний регистр
    text = text.lower()
    return text

# %%
all_text = ' '.join(df['select_stages'].apply(clean_text))

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# Отображаем облако слов
plt.figure(figsize=(10,  5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
words = all_text.split()

# Подсчитываем частоту каждого слова
word_counts = Counter(words)
word_counts
# Out:
# Counter({'резюме': 881,
#          'с': 872,
#          'собеседование': 861,
#          'скрининг': 792,
#          'тестовое': 529,
#          'задание': 486,
#          'интервью': 407,
#          'и': 279,
#          'в': 215,
#          'менеджером': 166,
#          'просмотр': 160,
#          'на': 157,
#          'нанимающим': 144,
#          'руководителем': 132,
#          'техническое': 113,
#          'возможно': 102,
#          'тестового': 88,
#          'командой': 87,
#          'по': 86,
#          'задания': 79,
#          'звонок': 73,
#          'отклик': 59,
#          'рекрутером': 54,
#          'встреча': 53,
#          'финальное': 46,
#          'портфолио': 45,
#          'офисе': 44,
#          'опцион': 44,
#          'этап': 43,
#          'трекере': 40,
#          'опционально': 39,
#          'выполнение': 39,
#          'о': 38,
#          'фаундером': 33,
#          'телефонное': 32,
#          'созвон': 32,
#          'лидом': 30,
#          'онлайн': 29,
#          'заполнение': 29,
#          'директором': 27,
#          'карьерном': 27,
#          'тимлидом': 26,
#          'для': 25,
#          'если': 24,
#          'стажировка': 24,
#          'будет': 23,
#          'проверка': 23,
#          'анкеты': 22,
#          'знакомство': 22,
#          'к': 22,
#          'отдела': 22,
#          'небольшое': 22,
#          'сайте': 22,
#          'мы': 21,
#          'кандидата': 20,
#          'компании': 20,
#          'не': 19,
#          'оффер': 19,
#          'минут': 19,
#          'решение': 18,
#          'сопроводительного': 18,
#          'пожалуйста': 18,
#          'или': 17,
#          'первичное': 17,
#          'заданиеинтервью': 17,
#          'от': 17,
#          'письме': 17,
#          'работы': 17,
#          'день': 17,
#          'вопросы': 16,
#          'вакансию': 16,
#          'скринингинтервью': 16,
#          'ссылке': 16,
#          'срок': 15,
#          'после': 15,
#          'общение': 15,
#          'очное': 15,
#          'сопроводительном': 15,
#          'тестовый': 15,
#          'собеседования': 15,
#          'команды': 15,
#          'кто': 15,
#          'тех': 14,
#          'сопроводительное': 14,
#          'письма': 14,
#          'это': 14,
#          'как': 14,
#          'продукта': 14,
#          'проекта': 14,
#          'сео': 13,
#          'стажировку': 13,
#          'анкета': 13,
#          'чтобы': 13,
#          'продвижения': 13,
#          'ты': 13,
#          'прохождение': 13,
#          'финал': 13,
#          'ваших': 13,
#          'этапы': 13,
#          'обязательно': 12,
#          'письмо': 12,
#          'отбора': 12,
#          'нам': 12,
#          'практические': 12,
#          'предложениях': 12,
#          'области': 12,
#          'понимании': 12,
#          'партнера': 12,
#          'направления': 11,
#          'то': 11,
#          'кандидатом': 11,
#          'отбор': 11,
#          'неделя': 11,
#          'заявка': 11,
#          'вы': 10,
#          'тестирование': 10,
#          'техническим': 10,
#          'отклика': 10,
#          'стажировки': 10,
#          'нужно': 10,
#          'недели': 10,
#          'без': 9,
#          'результатам': 9,
#          'дня': 9,
#          'тебя': 9,
#          'заданием': 9,
#          'быть': 9,
#          'случае': 9,
#          'испытательный': 9,
#          'тест': 9,
#          'анкету': 9,
#          'можно': 9,
#          'принятие': 9,
#          'проектов': 8,
#          'месяца': 8,
#          'ссылку': 8,
#          'сто': 8,
#          'интервьютестовое': 8,
#          'генеральным': 8,
#          'тестовым': 8,
#          'до': 8,
#          'предварительное': 8,
#          'понять': 8,
#          'формы': 8,
#          'решения': 8,
#          'общее': 8,
#          'данные': 8,
#          'скринингтестовое': 8,
#          'теми': 8,
#          'себе': 7,
#          'специалистом': 7,
#          'что': 7,
#          'тим': 7,
#          'дней': 7,
#          'техсобес': 7,
#          'при': 7,
#          'вакансия': 7,
#          'также': 7,
#          'подбора': 7,
#          'необходимо': 7,
#          'расскажи': 7,
#          'короткое': 7,
#          'видео': 7,
#          'насколько': 7,
#          'времени': 7,
#          'из': 7,
#          'изучение': 7,
#          'работодателя': 7,
#          'финальная': 7,
#          'час': 7,
#          'ли': 7,
#          'знаний': 7,
#          'важно': 6,
#          'оформление': 6,
#          'более': 6,
#          'его': 6,
#          'беседа': 6,
#          'финальный': 6,
#          'ответь': 6,
#          'нами': 6,
#          'первый': 6,
#          'часа': 6,
#          'опыте': 6,
#          'навыках': 6,
#          'а': 6,
#          'написать': 6,
#          'месяц': 6,
#          'телефонный': 6,
#          'офер': 6,
#          'течение': 6,
#          'длительностью': 6,
#          'откликнуться': 6,
#          'компания': 6,
#          'которые': 6,
#          'кандидат': 6,
#          'время': 6,
#          'вакансии': 6,
#          'очная': 6,
#          'тебе': 6,
#          'сделать': 6,
#          'ссылка': 6,
#          'вам': 5,
#          'здесь': 5,
#          'первичный': 5,
#          'кандидатами': 5,
#          'оставшимся': 5,
#          'вопросам': 5,
#          'управления': 5,
#          'связь': 5,
#          'есть': 5,
#          'несколько': 5,
#          'презентация': 5,
#          'исполнительным': 5,
#          'телефону': 5,
#          'личное': 5,
#          'наша': 5,
#          'мин': 5,
#          'анкете': 5,
#          'поможет': 5,
#          'лучше': 5,
#          'так': 5,
#          'проект': 5,
#          'вместе': 5,
#          'ответы': 5,
#          'собеседовании': 5,
#          'оценки': 5,
#          'примеры': 5,
#          'потенциальным': 5,
#          'сб': 5,
#          'заполнить': 5,
#          'видеособеседование': 5,
#          'неоплачиваемая': 5,
#          'прохождения': 5,
#          'контактным': 5,
#          'лицом': 5,
#          'прием': 5,
#          'этапа': 5,
#          'обязательный': 5,
#          'файл': 5,
#          'тестовые': 5,
#          'сбор': 5,
#          'проекты': 5,
#          'недель': 5,
#          'могут': 5,
#          'тестовая': 5,
#          'подписание': 5,
#          'сопроводительным': 4,
#          'письмом': 4,
#          'навыки': 4,
#          'задачи': 4,
#          'проходит': 4,
#          'почему': 4,
#          'работать': 4,
#          'одно': 4,
#          'часов': 4,
#          'лайвкодинг': 4,
#          'том': 4,
#          'софтскиллам': 4,
#          'отклике': 4,
#          'во': 4,
#          'командойесли': 4,
#          'хочешь': 4,
#          'личная': 4,
#          'будем': 4,
#          'пробный': 4,
#          'экспертом': 4,
#          'своем': 4,
#          'оплачивается': 4,
#          'за': 4,
#          'заинтересовала': 4,
#          'самом': 4,
#          'технические': 4,
#          'краткое': 4,
#          'ссылки': 4,
#          'свои': 4,
#          'решил': 4,
#          'вопросов': 4,
#          'подходишь': 4,
#          'эту': 4,
#          'максимально': 4,
#          'честным': 4,
#          'тогда': 4,
#          'несовпадения': 4,
#          'потратим': 4,
#          'оба': 4,
#          'слишком': 4,
#          'много': 4,
#          'через': 4,
#          'задачки': 4,
#          'оценка': 4,
#          'этапазум': 4,
#          'руководителемзум': 4,
#          'ваши': 4,
#          'скринингинтервьютестовое': 4,
#          'мотивационное': 4,
#          'агентства': 4,
#          'техлидом': 4,
#          'итогам': 4,
#          'может': 4,
#          'про': 4,
#          'портфолиоинтервью': 4,
#          'тз': 4,
#          'вас': 4,
#          'лид': 4,
#          'откликом': 4,
#          'отклики': 4,
#          'информации': 4,
#          'нанимающей': 4,
#          'командойменеджером': 4,
#          'наставником': 4,
#          'период': 4,
#          'напиши': 4,
#          'интервьювозможно': 4,
#          'авитоссылка': 4,
#          'заинтересовал': 4,
#          'выйдет': 4,
#          'вышел': 4,
#          'уже': 4,
#          'рассказать': 3,
#          'интересно': 3,
#          'английском': 3,
#          'русском': 3,
#          'около': 3,
#          'получаса': 3,
#          'вводныепробные': 3,
#          'оплачиваемых': 3,
#          'центра': 3,
#          'продуктового': 3,
#          'дирекции': 3,
#          'цифровой': 3,
#          'трансформации': 3,
#          'пропущен': 3,
#          'дни': 3,
#          'трудоустройства': 3,
#          'хард': 3,
#          'чат': 3,
#          'успешно': 3,
#          'даем': 3,
#          'обратную': 3,
#          'эта': 3,
#          'вопроса': 3,
#          'забудь': 3,
#          'заполните': 3,
#          'форму': 3,
#          'которое': 3,
#          'разговор': 3,
#          'большом': 3,
#          'профессиональном': 3,
#          'достижении': 3,
#          'руководителемкомандой': 3,
#          'секции': 3,
#          'ее': 3,
#          'зум': 3,
#          'резюмеинтервью': 3,
#          'формате': 3,
#          'фаундерами': 3,
#          'собеседованиетестовое': 3,
#          'трекер': 3,
#          'гугл': 3,
#          'со': 3,
#          'чем': 3,
#          'второе': 3,
#          'рабочих': 3,
#          'основателем': 3,
#          'опыт': 3,
#          'нашим': 3,
#          'этом': 3,
#          'руководителями': 3,
#          'самостоятельное': 3,
#          'теста': 3,
#          'нашего': 3,
#          'короткий': 3,
#          'второй': 3,
#          'нас': 3,
#          'готовы': 3,
#          'знание': 3,
#          'руководством': 3,
#          'тестовоеинтервью': 3,
#          'того': 3,
#          'возможна': 3,
#          'формат': 3,
#          'будут': 3,
#          'результатов': 3,
#          'хорошо': 3,
#          'ним': 3,
#          'продактом': 3,
#          'подходим': 3,
#          'оплачиваемый': 3,
#          'работа': 3,
#          'базе': 3,
#          'интервьюсобеседование': 3,
#          'безопасности': 3,
#          'два': 3,
#          'меняться': 3,
#          'выполнения': 3,
#          'работу': 3,
#          'над': 3,
#          'звонокзнакомство': 3,
#          'разработчиком': 3,
#          'кандидатов': 3,
#          'пройти': 3,
#          'проджектом': 3,
#          'перед': 3,
#          'могла': 3,
#          'внести': 3,
#          'свою': 3,
#          'систему': 3,
#          'направление': 3,
#          'тобой': 3,
#          'укажи': 3,
#          'маркетингу': 3,
#          'маркетинга': 3,
#          'персоналу': 3,
#          'их': 3,
#          'иили': 3,
#          'бесплатная': 3,
#          'прошли': 3,
#          'видеоинтервью': 3,
#          'аналитиком': 3,
#          'всех': 3,
#          'момент': 3,
#          'тестовому': 3,
#          'заданию': 3,
#          'желательно': 3,
#          'дополнительные': 3,
#          'итоговое': 3,
#          'продактменеджером': 3,
#          'проектах': 2,
#          'своей': 2,
#          'мотивации': 2,
#          'режиме': 2,
#          'который': 2,
#          'тимлидомруководителем': 2,
#          'аккуратное': 2,
#          'мотивация': 2,
#          'пишите': 2,
#          'причинами': 2,
#          'вопросами': 2,
#          'логику': 2,
#          'языке': 2,
#          'удаленно': 2,
#          'дается': 2,
#          'опыта': 2,
#          'департамента': 2,
#          'успешными': 2,
#          'небольшой': 2,
#          'принимается': 2,
#          'обратная': 2,
#          'студии': 2,
#          'возможностью': 2,
#          'психологом': 2,
#          'звоноквстреча': 2,
#          'вами': 2,
#          'вышлем': 2,
#          'выполнено': 2,
#          'назначаем': 2,
#          'принимаем': 2,
#          'собес': 2,
#          'нашей': 2,
#          'получить': 2,
#          'рассматриваем': 2,
#          'лидомв': 2,
#          'присылай': 2,
#          'свой': 2,
#          'профиль': 2,
#          'заданиесобеседование': 2,
#          'своих': 2,
#          'выполнить': 2,
#          'обучение': 2,
#          'попасть': 2,
#          'готовится': 2,
#          'этой': 2,
#          'крининг': 2,
#          'приложить': 2,
#          'среднем': 2,
#          'об': 2,
#          'анализа': 2,
#          'офлайн': 2,
#          'лидами': 2,
#          'видеозадание': 2,
#          'просим': 2,
#          'ответить': 2,
#          'короткого': 2,
#          'следующие': 2,
#          'позициюпостарайся': 2,
#          'осознатьанкета': 2,
#          'приём': 2,
#          'собеседованиезнакомство': 2,
#          'старшим': 2,
#          'рекрутмента': 2,
#          'напишите': 2,
#          'поймем': 2,
#          'дальше': 2,
#          'собседование': 2,
#          'отделом': 2,
#          'разработки': 2,
#          'гуглформы': 2,
#          'звоноксобеседование': 2,
#          'прикрепи': 2,
#          'сопроводительному': 2,
#          'письму': 2,
#          'ответ': 2,
#          'отклику': 2,
#          'приложите': 2,
#          'вашего': 2,
#          'текст': 2,
#          'менеджеров': 2,
#          'технический': 2,
#          'общий': 2,
#          'текущим': 2,
#          'пм': 2,
#          'углубленный': 2,
#          'устраивают': 2,
#          'переходим': 2,
#          'этапу': 2,
#          'миниинтервью': 2,
#          'ассистентом': 2,
#          'тестирования': 2,
#          'заявки': 2,
#          'вопрос': 2,
#          'успешной': 2,
#          'стажировке': 2,
#          'проектастартапа': 2,
#          'вакансииинтервью': 2,
#          'заказчиком': 2,
#          'путем': 2,
#          'задач': 2,
#          'реальном': 2,
#          'прикреплена': 2,
#          'входит': 2,
#          'составление': 2,
#          'под': 2,
#          'партнером': 2,
#          'обучениестажировка': 2,
#          'задачами': 2,
#          'справился': 2,
#          'раньше': 2,
#          'зависимости': 2,
#          'где': 2,
#          'поговорим': 2,
#          'твой': 2,
#          'друг': 2,
#          'рады': 2,
#          'заданиетехническое': 2,
#          'обучения': 2,
#          'каждая': 2,
#          'простых': 2,
#          'задачах': 2,
#          'одном': 2,
#          'коммерческих': 2,
#          'заданиесобеседованиетрудоустройство': 2,
#          'базы': 2,
#          'экзамен': 2,
#          'необходимости': 2,
#          'созвонинтервью': 2,
#          'службы': 2,
#          'местами': 2,
#          'рассмотрение': 2,
#          'тесткейсов': 2,
#          'решённых': 2,
#          'должно': 2,
#          'примерное': 2,
#          'расширение': 2,
#          'кодом': 2,
#          'приглашаем': 2,
#          'успешного': 2,
#          'участие': 2,
#          'установочном': 2,
#          'вебинаре': 2,
#          'комментариям': 2,
#          'карьерного': 2,
#          'консультантаменеджера': 2,
#          'прикреплено': 2,
#          'человеке': 2,
#          'пет': 2,
#          'проекте': 2,
#          'других': 2,
#          'посмотрим': 2,
#          'у': 2,
#          'поле': 2,
#          'какими': 2,
#          'такие': 2,
#          'вкс': 2,
#          'получение': 2,
#          'процесс': 2,
#          'службой': 2,
#          'мотивационного': 2,
#          'места': 2,
#          'своё': 2,
#          'работ': 2,
#          'онлайнсобеседование': 2,
#          'оплачиваемая': 2,
#          'недельная': 2,
#          'дату': 2,
#          'скайпинтервью': 2,
#          'тестов': 2,
#          'будущим': 2,
#          'этот': 2,
#          'но': 2,
#          'разработке': 2,
#          'реализованных': 2,
#          'выполненным': 2,
#          'секция': 2,
#          'встречу': 2,
#          'проводим': 2,
#          'которыми': 2,
#          'оплачиваемое': 2,
#          'сразу': 2,
#          'позицию': 2,
#          'постарайся': 2,
#          'осознать': 2,
#          'обсуждается': 2,
#          'индивидуально': 2,
#          'штат': 2,
#          'аудиозвонок': 2,
#          'месяцаесли': 2,
#          'все': 2,
#          'давай': 2,
#          'пообщаемся': 2,
#          'понравилась': 2,
#          'звонокинтервью': 2,
#          'опциональное': 2,
#          'прикрепить': 2,
#          'командойвозможно': 2,
#          'технических': 2,
#          'раз': 2,
#          'совместной': 2,
#          'набросать': 2,
#          'дорожную': 2,
#          'карту': 2,
#          'даст': 2,
#          'подойдет': 2,
#          'данный': 2,
#          'ый': 2,
#          'берут': 2,
#          'идёт': 2,
#          'её': 2,
#          'переходишь': 2,
#          'знакомишься': 2,
#          'условиями': 2,
#          'подписываешь': 2,
#          'приступаешь': 2,
#          'уйти': 2,
#          'любой': 2,
#          'приглашение': 2,
#          'рекрутеру': 2,
#          'собеседованиедля': 2,
#          'участия': 2,
#          'отборе': 2,
#          'напрямую': 2,
#          'чётко': 2,
#          'плану': 2,
#          'текущие': 2,
#          'прикладные': 2,
#          'стек': 2,
#          'скиллы': 2,
#          'готовность': 2,
#          'выполнению': 2,
#          'название': 2,
#          'партнерассылка': 2,
#          'рекомендаций': 2,
#          'работали': 2,
#          'каком': 2,
#          'уровне': 2,
#          'общая': 2,
#          'резюметехническое': 2,
#          'техническая': 2,
#          'часть': 2,
#          'москве': 2,
#          'ообласти': 2,
#          'проверку': 2,
#          'аналитических': 2,
#          'способностей': 2,
#          'непосредственным': 2,
#          'договора': 2,
#          'правильных': 2,
#          'ответов': 2,
#          'опицон': 2,
#          'испытательная': 2,
#          'соо': 1,
#          'коротко': 1,
#          'заслуги': 1,
#          'увлечения': 1,
#          'которых': 1,
#          'довелось': 1,
#          'участвовать': 1,
#          'компанию': 1,
#          'обычно': 1,
#          'оно': 1,
#          'текстовом': 1,
#          'голосовом': 1,
#          'сами': 1,
#          'установите': 1,
#          'дз': 1,
#          'командойважнонесмотря': 1,
#          'требуется': 1,
#          'разговорный': 1,
#          'английский': 1,
#          'язык': 1,
#          'примут': 1,
#          'этапе': 1,
#          'работают': 1,
#          'русскоязычные': 1,
#          'рекрутеры': 1,
#          'задние': 1,
#          'согласование': 1,
#          'оффераэтапы': 1,
#          'займут': 1,
#          'подробный': 1,
#          'фидбек': 1,
#          'каждого': 1,
#          'этапатестовое': 1,
#          'присылается': 1,
#          'кандидатам': 1,
#          'опытными': 1,
#          'ведется': 1,
#          'проектам': 1,
#          'объемом': 1,
#          'резюметестовое': 1,
#          'офлайнвстреча': 1,
#          'телемосте': 1,
#          'разработчик': 1,
#          'расскажет': 1,
#          'чего': 1,
#          'хочет': 1,
#          'попросит': 1,
#          'работе': 1,
#          'ревьюверами': 1,
#          'курсев': 1,
#          'течении': 1,
#          'испытательные': 1,
#          'оплачиваются': 1,
#          'днявыход': 1,
#          'дальнейшего': 1,
#          'пришлите': 1,
#          'внутренний': 1,
#          'примерами': 1,
#          'написанного': 1,
#          'кодаответным': 1,
#          'сообщением': 1,
#          'заданиеесли': 1,
#          'минутчерез': 1,
#          'гитхаб': 1,
#          'три': 1,
#          'именно': 1,
#          'твоя': 1,
#          'идеальная': 1,
#          'командаотклики': 1,
#          'стажировочный': 1,
#          'связи': 1,
#          'софтскилловое': 1,
#          'интервьюром': 1,
#          'руководителемнапиши': 1,
#          'увлечениях': 1,
#          'пожелания': 1,
#          'уровню': 1,
#          'заработной': 1,
#          'платы': 1,
#          'направленияиспытательный': 1,
#          'гита': 1,
#          'компетенций': 1,
#          'диром': 1,
#          'тел': 1,
#          'мб': 1,
#          'кандидатомвстреча': 1,
#          'команду': 1,
#          'круто': 1,
#          'справиться': 1,
#          'отправим': 1,
#          'смотрим': 1,
#          'зовем': 1,
#          'получаем': 1,
#          'тестовоесобеседование': 1,
#          'очноеиспытательный': 1,
#          'сроктестовое': 1,
#          'заключаться': 1,
#          'проработке': 1,
#          'кейса': 1,
#          'например': 1,
#          'запуску': 1,
#          'большая': 1,
#          'профильная': 1,
#          'научная': 1,
#          'конференция': 1,
#          'создать': 1,
#          'стратегию': 1,
#          'материалов': 1,
#          'конференции': 1,
#          'бренда': 1,
#          'анализ': 1,
#          'сопоставление': 1,
#          'заявленными': 1,
#          'требованиями': 1,
#          'проведение': 1,
#          'группы': 1,
#          'офис': 1,
#          'лучшие': 1,
#          'рекрутера': 1,
#          'откликаемся': 1,
#          'релевантные': 1,
#          'общей': 1,
#          'заинтересованности': 1,
#          'поверхностного': 1,
#          'рекламных': 1,
#          'кабинетов': 1,
#          'изучения': 1,
#          'сайтов': 1,
#          'заданиефинальное': 1,
#          'тимтех': 1,
#          'скринингтестовоеинтервью': 1,
#          'заданиевстреча': 1,
#          'вопросыкакое': 1,
#          'твоё': 1,
#          'самое': 1,
#          'значимое': 1,
#          'достижениепочему': 1,
#          'нашу': 1,
#          'задублировать': 1,
#          'отправить': 1,
#          'откликов': 1,
#          'выбор': 1,
#          'претендентов': 1,
#          'получится': 1,
#          'отлично': 1,
#          'обозначением': 1,
#          'интересен': 1,
#          'лидомсобственником': 1,
#          'одобрения': 1,
#          'первое': 1,
#          'хотите': 1,
#          'стать': 1,
#          'частью': 1,
#          'откликнитесь': 1,
#          'позиции': 1,
#          'нанималитак': 1,
#          'внимательны': 1,
#          'профессионально': 1,
#          'подходите': 1,
#          'вопросу': 1,
#          'рекрутероминтервью': 1,
#          'логикув': 1,
#          'тимтехлидом': 1,
#          'софтскилам': 1,
#          'кем': 1,
#          'техника': 1,
#          'пройдёт': 1,
#          'кофаундером': 1,
#          'всё': 1,
#          'возможностей': 1,
#          'сервиса': 1,
#          'софт': 1,
#          'скиллам': 1,
#          'котором': 1,
#          'показываете': 1,
#          'базовые': 1,
#          'знания': 1,
#          'выдается': 1,
#          'руки': 1,
#          'найм': 1,
#          'ждём': 1,
#          'такое': 1,
#          'релевантность': 1,
#          'контекстной': 1,
#          'рекламе': 1,
#          'какой': 1,
#          'формуле': 1,
#          'рассчитывается': 1,
#          'средний': 1,
#          'кликабельности': 1,
#          'называется': 1,
#          'сервис': 1,
#          'пользовательского': 1,
#          'интереса': 1,
#          'ключевых': 1,
#          'фраз': 1,
#          'выбери': 1,
#          'один': 1,
#          'правильный': 1,
#          'яндекс': 1,
#          'метрика': 1,
#          'демонстрация': 1,
#          'одному': 1,
#          'экрану': 1,
#          'компанииздорово': 1,
#          'контента': 1,
#          'нравится': 1,
#          'был': 1,
#          'коммерческий': 1,
#          'контент': 1,
#          'владельцем': 1,
#          'срокстажировка': 1,
#          'предложить': 1,
#          'заголовок': 1,
#          'поста': 1,
#          'инстаграма': 1,
#          'оффермитинг': 1,
#          'кандитатомкой': 1,
#          'числе': 1,
#          'полиграф': 1,
#          'направляет': 1,
#          'рекрутер': 1,
#          'доступно': 1,
#          'крауд': 1,
#          'ревью': 1,
#          'разработчика': 1,
#          'положительное': 1,
#          'вывод': 1,
#          'заместителем': 1,
#          'генерального': 1,
#          'директора': 1,
#          'гайд': 1,
#          'этапам': 1,
#          'карьерный': 1,
#          'программы': 1,
#          'куратором': 1,
#          'собеседованиезвонок': 1,
#          'ответом': 1,
#          'выйти': 1,
#          'ментором': 1,
#          'прикрепленной': 1,
#          'руководитель': 1,
#          'продажам': 1,
#          'внутреннюю': 1,
#          'полне': 1,
#          'ответа': 1,
#          'достаточно': 1,
#          'заполнил': 1,
#          'самопрезентация': 1,
#          'кандидате': 1,
#          'коммерческого': 1,
#          'предложения': 1,
#          'наставника': 1,
#          'тестовоознакомительная': 1,
#          'погружения': 1,
#          'внутренние': 1,
#          'процессы': 1,
#          'последующей': 1,
#          'оценкой': 1,
#          'высылается': 1,
#          'преоффер': 1,
#          'она': 1,
#          'необходима': 1,
#          'справится': 1,
#          'предстоящими': 1,
#          'реюзме': 1,
#          'мес': 1,
#          'кандидату': 1,
#          'давать': 1,
#          'реализацию': 1,
#          'смотреть': 1,
#          'он': 1,
#          'ними': 1,
#          'закончиться': 1,
#          'сможет': 1,
#          'убедиться': 1,
#          'сотрудник': 1,
#          'справляется': 1,
#          'поставленными': 1,
#          'требуемой': 1,
#          'нагрузкой': 1,
#          'заключат': 1,
#          'договор': 1,
#          'выполненное': 1,
#          'любители': 1,
#          'формальностей': 1,
#          'затягивания': 1,
#          'процессов': 1,
#          'найму': 1,
#          'ждеттестовое': 1,
#          'твои': 1,
#          'навыкисобеседование': 1,
#          'потенциальными': 1,
#          'коллегами': 1,
#          'максимум': 1,
#          'наши': 1,
#          'задачифинальное': 1,
#          'продаж': 1,
#          'окончательно': 1,
#          'убедимся': 1,
#          'другубудем': 1,
#          'расскажешь': 1,
#          'погружена': 1,
#          'спортивную': 1,
#          'повестку': 1,
#          'интервьюна': 1,
#          'данной': 1,
#          'позици': 1,
#          'предусмотрена': 1,
#          'окончанию': 1,
#          'продолжение': 1,
#          'практическая': 1,
#          'программистом': 1,
#          'сторона': 1,
#          'рассказывает': 1,
#          'оценку': 1,
#          'логики': 1,
#          'мышления': 1,
#          'главным': 1,
#          'дизайнером': 1,
#          'подразделения': 1,
#          ...})

# %% [markdown]
# Резюме, собеседование, тестовое (задание), интервью - самые частые слова, встречающиеся в вакансиях.

# %% [markdown]
# ### Кодирование новых признаков
# [Назад к содержанию](#section_id)

# %% [markdown]
# Для исследования выведем несколько признаков на основе имеющихся данных для облегчения формирования групп для исследования.
# У нас будет 4 категории признаков, три из которых это кодирание каждой категории из нескольких категориальных столбцов
#  1. Признаки из столбцов, где в каждоый ячейке перечислено несколько значениий.
#
# -  `city_count` - покажет число городов, в которых предполагается работа независимо от формата.
# - `work_format_count` - покажет число форматов работы, предлагаемых по вакансии.
# -  `job_time_count` - покажет количество форматов занятости, предлагаемых заказчиком
# -  `one_city` - булевый признак. Вакансия представлена в одном городе (1) или в нескольних (0)
# -  `full_salary` - булевый признак, для вакансии полностью указана зарплатная вилка.

# %%
df['city_count'] = df['city'].str.split(', ').apply(lambda x: len(set(x)))
df['work_format_count'] = df['work_format'].str.split(', ').apply(lambda x: len(set(x)))
df['job_time_count'] = df['job_time_type'].str.split(', ').apply(lambda x: len(set(x)))

# %%
df['1_one_city'] = (df['city_count'] ==  1)
df['1_full_salary'] = df['salary_max'].notnull() & df['salary_min'].notnull()
df['1_cities'] = df['city'].str.split(', ')
df['1_is_moscow'] = df['1_cities'].apply(lambda x:   1 if 'Москва' in x else   0)
df['1_is_single_moscow'] = df.apply(lambda row:  1 if row['city_count'] ==  1 and row['1_is_moscow'] ==  1 else  0, axis=1)

# %% [markdown]
# 2. Кодирование столбца `job_time_type`
#
# Если в описании вакансии встречается определенный тип формата занятости, то тогда будет присвоено значение True

# %%
df['job_time'] = df['job_time_type'].str.split(', ')
df['2_full_time'] = df['job_time'].apply(lambda x: 'Полная' in x)
df['2_part_time'] = df['job_time'].apply(lambda x: 'Частичная' in x)
df['2_project_time'] = df['job_time'].apply(lambda x: 'Проектная' in x)
df['2_jun_time'] = df['job_time'].apply(lambda x: 'Стажировка' in x)
df['2_vol_time'] = df['job_time'].apply(lambda x: 'Волонтерство' in x)

# %% [markdown]
# 3. Кодирование столбца `law_format`
#
# Если в описании вакансии встречается определенный тип формата оформления, то тогда будет присвоено значение True

# %%
df['law_types'] = df['law_format'].str.split(', ')
df['3_is_ip'] = df['law_types'].apply(lambda x: 'ИП' in x)
df['3_is_gph'] = df['law_types'].apply(lambda x: 'ГПХ' in x)
df['3_is_freel'] = df['law_types'].apply(lambda x: 'Самозанятость' in x)
df['3_is_conrtact'] = df['law_types'].apply(lambda x: 'Контракт' in x)
df['3_is_emp_con'] = df['law_types'].apply(lambda x: 'Трудовой договор' in x)

# %% [markdown]
# 4. Кодирование столбца `status`

# %%
df['st_arhive'] = df['status'].apply(lambda x: 'Архив' in x)
df['st_closed'] = df['status'].apply(lambda x: 'Закрыта нами' in x)
df['st_rej'] = df['status'].apply(lambda x: 'Отклонена' in x)
df['st_activ'] = df['status'].apply(lambda x: 'Активна' in x)
df['st_consid'] = df['status'].apply(lambda x: 'На рассмотрении' in x)

# Т.к. нас интересуют вакансии, закрытые нами, определим ее в отдельный столбец.
df['is_closed'] = df['status'].apply(lambda x:   1 if 'Закрыта нами' in x else   0)

# %% [markdown]
#  5. Кодирование столбца `work_format`

# %%
df['work_types'] = df['work_format'].str.split(', ')
df['5_is_udal'] = df['work_types'].apply(lambda x: 'Удаленка' in x)
df['5_is_office'] = df['work_types'].apply(lambda x: 'Офис' in x)
df['5_is_gibrid'] = df['work_types'].apply(lambda x: 'Гибрид' in x)

# %% [markdown]
# - Таким образом мы можем просмотреть взаимосвязи каждой категории друг с другом.
# - Но в этом так же есть и побочный эффект - если в ячейке будет указано несколько значений, то между ними возможна сильная положительная связь

# %% [markdown]
# ## EDA
# [Назад к содержанию](#section_id)

# %% [markdown]
# ### Матрица корреляции

# %% [markdown]
# Так как матрица получится слишком большая, то ниже будет проведено ранжирование пар корреляции и формирование их в отдельную таблицу

# %%
#построим и отрисуем матрицу корреляций
cm = df.drop(['id'],axis = 1).corr(method='spearman').round(2)
cm_masked = cm.mask(cm ==  1)

# #нарисуем тепловую карту с подписями для матрицы корреляций
plt.figure(figsize=(20,20))
sns.heatmap(cm_masked, 
            annot=True, 
            square=True,
            cmap='RdYlGn', 
            center = 0)
ax = plt.gca()
ax.set_title('Хитмэп матрицы корреляции');

plt.show();

# %%
cm_df = pd.DataFrame(cm_masked)

# %%
pairs = cm_df.unstack().reset_index()
pairs.columns = ['var_1', 'var_2', 'corr']

# Сортировка DataFrame по значениям корреляции
pairs_sorted = pairs.sort_values(by='corr', ascending=False)

# Вывод ранжированных пар
pairs_sorted

pairs_sorted['unique_pair'] = pairs_sorted.apply(lambda row: tuple(sorted([row['var_1'], row['var_2']])), axis=1)

# Удаление дубликатов по уникальному индексу
pairs_sorted = pairs_sorted.drop_duplicates(subset='unique_pair', keep='first')

# Удаление временного столбца 'unique_pair'
pairs_sorted = pairs_sorted.drop(columns=['unique_pair'])

# Вывод обновленного DataFrame
pairs_sorted
# Out:
#                   var_1               var_2  corr
# 255   work_format_count         5_is_gibrid  0.86
# 364         1_is_moscow  1_is_single_moscow  0.84
# 270      job_time_count         2_part_time  0.81
# 488      2_project_time      job_time_count  0.78
# 595             3_is_ip            3_is_gph  0.77
# ...                 ...                 ...   ...
# 891           st_consid           st_consid   NaN
# 924           is_closed           is_closed   NaN
# 957           5_is_udal           5_is_udal   NaN
# 990         5_is_office         5_is_office   NaN
# 1023        5_is_gibrid         5_is_gibrid   NaN
#
# [528 rows x 3 columns]

# %% [markdown]
# Далее проранжирую в таблице значения корреляций для удобства
# - 0,01 < r <= 0,29 – слабая положительная связь,
# - 0,30 < r <= 0,69 – умеренная положительная связь,
# - 0,70 < r <= 1,00 – сильная положительная связь,
# - -0,01 > r >= -0,29 – слабая отрицательная связь,
# - -0,30 > r >= -0,69 – умеренная отрицательная связь,
# - -0,70 > r >= -1,00 – сильная отрицательная связь.

# %%
def assign_correlation_range(correlation):
    if correlation > 0.69 and correlation <= 1:
        return 'Сильная положительная'
    elif correlation > 0.3 and correlation <= 0.69:
        return 'Умеренная положительная'
    elif correlation >= 0.01 and correlation <= 0.3:
        return 'Слабая положительная'
    elif correlation <= -0.01 and correlation >= -0.29:
        return 'Слабая отрицательная'
    elif correlation <= -0.3 and correlation >= -0.69:
        return 'Умеренная отрицательная'
    elif correlation <= -0.7 and correlation >= -1:
        return 'Сильная отрицательная'
    else:
        return 'Нулевая, полная, не определена'

pairs_sorted['cor_range'] = pairs_sorted['corr'].apply(assign_correlation_range)

# %%
# Посмотрим, как распределяются пары корреляций
pairs_sorted.cor_range.value_counts().to_frame()
# Out:
#                                 cor_range
# Слабая отрицательная                  221
# Слабая положительная                  214
# Нулевая, полная, не определена         52
# Умеренная положительная                21
# Умеренная отрицательная                12
# Сильная положительная                   7
# Сильная отрицательная                   1

# %% [markdown]
# Заодно проанализируем все получившиеся категории

# %% [markdown]
# ### Анализ пар корреляций
# [Назад к содержанию](#section_id)

# %% [markdown]
# #### Пары со связью "Сильная положительная"

# %%
pairs_sorted.query('cor_range== "Сильная положительная"')
# Out:
#                  var_1               var_2  corr              cor_range
# 255  work_format_count         5_is_gibrid  0.86  Сильная положительная
# 364        1_is_moscow  1_is_single_moscow  0.84  Сильная положительная
# 270     job_time_count         2_part_time  0.81  Сильная положительная
# 488     2_project_time      job_time_count  0.78  Сильная положительная
# 595            3_is_ip            3_is_gph  0.77  Сильная положительная
# 629           3_is_gph       3_is_conrtact  0.74  Сильная положительная
# 658         3_is_freel             3_is_ip  0.74  Сильная положительная

# %% [markdown]
# 1. Описанная выше теория подтверждается - высоко коррелируют значения, взятые из одного столбца.
# 2. При этом так же есть высокие корреляции определенного типа работы и общего количества типов, указанных в изначальном столбце, например:
#    -  гибрид `5_is_gibrid` в основном представлен в вакансиях, как дополнительный формат, на что указывает то, что с увеличением числа опций, этот формат так же присутствует.
#    -  частичная занятость `2_part_time` и  проектная занятость `2_project_time` часто представлены, как дополнительные опции `job_time_count`

# %% [markdown]
# #### Пары со связью "Умеренная положительная"
# [Назад к содержанию](#section_id)

# %%
pairs_sorted.query('cor_range== "Умеренная положительная"')
# Out:
#                var_1               var_2  corr                cor_range
# 65        resp_count          view_count  0.69  Умеренная положительная
# 597          3_is_ip       3_is_conrtact  0.69  Умеренная положительная
# 100       salary_min          salary_max  0.68  Умеренная положительная
# 967      5_is_office   work_format_count  0.68  Умеренная положительная
# 552       2_vol_time      job_time_count  0.64  Умеренная положительная
# 463      2_part_time      2_project_time  0.62  Умеренная положительная
# 529       2_jun_time          2_vol_time  0.61  Умеренная положительная
# 520       2_jun_time      job_time_count  0.58  Умеренная положительная
# 628         3_is_gph          3_is_freel  0.58  Умеренная положительная
# 1022     5_is_gibrid         5_is_office  0.54  Умеренная положительная
# 497   2_project_time          2_vol_time  0.51  Умеренная положительная
# 558       2_vol_time         2_part_time  0.49  Умеренная положительная
# 438      2_full_time        3_is_emp_con  0.47  Умеренная положительная
# 661       3_is_freel       3_is_conrtact  0.46  Умеренная положительная
# 300       1_one_city  1_is_single_moscow  0.44  Умеренная положительная
# 527       2_jun_time      2_project_time  0.38  Умеренная положительная
# 464      2_part_time          2_jun_time  0.36  Умеренная положительная
# 109       salary_min         2_full_time  0.35  Умеренная положительная
# 61        view_count           5_is_udal  0.33  Умеренная положительная
# 735     3_is_emp_con         5_is_gibrid  0.33  Умеренная положительная
# 734     3_is_emp_con         5_is_office  0.32  Умеренная положительная

# %% [markdown]
# Пары из совпадающих столбцов опустим.
# - Справедливая корреляция количества просмотров и откликов вакансий
# - Корреляция минимальной и максимальной ЗП выглядит так же логично, если учесть, что связь показана для строк, в которых вилка указана полностью.
# - Наблюдается корреляция между указанием минимальной ЗП `salary_min` и типом занятости "Полная" `2_full_time`
# - Наблюдается связь между количество просмотров и опцией "удаленка"
# - Так же есть связь между заключением трудового дороговора `3_is_emp_con` и вариантами устройсва гибрид `5_is_gibrid` и офис `5_is_office`

# %% [markdown]
# #### Пары со связью "Слабая положительная"
# [Назад к содержанию](#section_id)

# %%
pairs_sorted.query('cor_range== "Слабая положительная"').head(20)
# Out:
#                  var_1              var_2  corr             cor_range
# 707       3_is_emp_con         salary_min  0.30  Слабая положительная
# 963        5_is_office         salary_min  0.29  Слабая положительная
# 711       3_is_emp_con  work_format_count  0.28  Слабая положительная
# 708       3_is_emp_con         salary_max  0.27  Слабая положительная
# 948          5_is_udal         3_is_freel  0.26  Слабая положительная
# 973        5_is_office        2_full_time  0.25  Слабая положительная
# 723       3_is_emp_con           3_is_gph  0.25  Слабая положительная
# 276     job_time_count         3_is_freel  0.25  Слабая положительная
# 500     2_project_time         3_is_freel  0.24  Слабая положительная
# 93          resp_count          5_is_udal  0.23  Слабая положительная
# 447        2_full_time        5_is_gibrid  0.23  Слабая положительная
# 237  work_format_count        2_full_time  0.23  Слабая положительная
# 943          5_is_udal     2_project_time  0.23  Слабая положительная
# 127         salary_min        5_is_gibrid  0.22  Слабая положительная
# 936          5_is_udal     job_time_count  0.22  Слабая положительная
# 161          task_link         view_count  0.22  Слабая положительная
# 420        2_full_time         salary_max  0.21  Слабая положительная
# 477        2_part_time          5_is_udal  0.21  Слабая положительная
# 964        5_is_office         salary_max  0.21  Слабая положительная
# 468        2_part_time         3_is_freel  0.21  Слабая положительная

# %% [markdown]
# - Наблюдается связь между откликами `resp_count` и удаленной работой `5_is_udal`
# - При устройстве по трудовому договору и при устройстве в офис `3_is_emp_con` часто указана минимальная зп
# - Трудовой договор и ГПХ так же имеют связь.
# - Проектная работа и самозанятость так же имеют слабую связь.

# %% [markdown]
# #### Пары со связью "Слабая отрицательная"
# [Назад к содержанию](#section_id)

# %%
pairs_sorted.query('cor_range== "Слабая отрицательная"').tail(20)
# Out:
#             var_1              var_2  corr             cor_range
# 909     is_closed        2_full_time -0.18  Слабая отрицательная
# 440   2_full_time          st_closed -0.18  Слабая отрицательная
# 935     5_is_udal  work_format_count -0.19  Слабая отрицательная
# 54     view_count       3_is_emp_con -0.20  Слабая отрицательная
# 993   5_is_gibrid         view_count -0.20  Слабая отрицательная
# 55     view_count          st_arhive -0.20  Слабая отрицательная
# 87     resp_count          st_arhive -0.21  Слабая отрицательная
# 129    salary_max         view_count -0.21  Слабая отрицательная
# 941     5_is_udal        2_full_time -0.21  Слабая отрицательная
# 478   2_part_time        5_is_office -0.22  Слабая отрицательная
# 712  3_is_emp_con     job_time_count -0.22  Слабая отрицательная
# 968   5_is_office     job_time_count -0.22  Слабая отрицательная
# 157    salary_max          5_is_udal -0.22  Слабая отрицательная
# 62     view_count        5_is_office -0.23  Слабая отрицательная
# 975   5_is_office     2_project_time -0.23  Слабая отрицательная
# 718  3_is_emp_con        2_part_time -0.24  Слабая отрицательная
# 719  3_is_emp_con     2_project_time -0.25  Слабая отрицательная
# 980   5_is_office         3_is_freel -0.25  Слабая отрицательная
# 720  3_is_emp_con         2_jun_time -0.26  Слабая отрицательная
# 855      st_activ          st_arhive -0.26  Слабая отрицательная

# %% [markdown]
# На что можно обратить внимание
# - `view_count` -  `5_is_office` - работа в офисе становится малопривлекательной.
# - `3_is_emp_con`- `2_jun_time` - стажировку не хотят оформлять официально.
# - `5_is_office`- `2_project_time` - проектная работа возможно не подразумевает обязательное посещение офиса.
# - `2_part_time`- `5_is_office` - неполная занятость возможно тоже не обязывает посещать регулярно офис.

# %% [markdown]
# #### Пары со связью "Умеренная отрицательная"
# [Назад к содержанию](#section_id)

# %%
pairs_sorted.query('cor_range== "Умеренная отрицательная"').head(20)
# Out:
#                    var_1           var_2  corr                cor_range
# 763            st_arhive       st_consid -0.30  Умеренная отрицательная
# 430          2_full_time     2_part_time -0.31  Умеренная отрицательная
# 931            5_is_udal      salary_min -0.32  Умеренная отрицательная
# 733         3_is_emp_con       5_is_udal -0.32  Умеренная отрицательная
# 431          2_full_time  2_project_time -0.33  Умеренная отрицательная
# 761            st_arhive          st_rej -0.33  Умеренная отрицательная
# 432          2_full_time      2_jun_time -0.40  Умеренная отрицательная
# 390   1_is_single_moscow      city_count -0.44  Умеренная отрицательная
# 1021         5_is_gibrid       5_is_udal -0.44  Умеренная отрицательная
# 764            st_arhive       is_closed -0.63  Умеренная отрицательная
# 791            st_closed       st_arhive -0.63  Умеренная отрицательная
# 958            5_is_udal     5_is_office -0.64  Умеренная отрицательная

# %% [markdown]
# В основном представлены пары из одних столцов.
# - Отрицательная корреляция между удаленкой и указанием минимальной зп
# - Заключение трудового договора `3_is_emp_con`и `5_is_udal` так же отрицательно коррелирует, что может говорить о том, что для удаленщиков возможно лучший вариант заключить ГПХ.

# %% [markdown]
# #### Пары со связью "Сильная отрицательная"
# [Назад к содержанию](#section_id)

# %%
pairs_sorted.query('cor_range== "Сильная отрицательная"')
# Out:
#           var_1       var_2  corr              cor_range
# 294  1_one_city  city_count  -1.0  Сильная отрицательная

# %% [markdown]
# Столбец с указанием одного города справделиво отлицательно коррелирует с увеличением числа городов в `city_count`

# %% [markdown]
# #### Пары со связью "Нулевая(полная, не определена)"
# [Назад к содержанию](#section_id)

# %%
display(pairs_sorted.query('cor_range== "Нулевая, полная, не определена"').head(20))
pairs_sorted.query('cor_range== "Нулевая, полная, не определена"').tail(5)
# Out:
#                   var_1               var_2  corr  \
# 340       1_full_salary          3_is_freel   0.0
# 53           view_count       3_is_conrtact  -0.0
# 683       3_is_conrtact         1_is_moscow   0.0
# 684       3_is_conrtact  1_is_single_moscow   0.0
# 82           resp_count             3_is_ip  -0.0
# 211          city_count            3_is_gph  -0.0
# 307          1_one_city            3_is_gph  -0.0
# 557          2_vol_time         2_full_time  -0.0
# 645          3_is_freel           task_link  -0.0
# 222          city_count         5_is_office   0.0
# 318          1_one_city         5_is_office   0.0
# 443         2_full_time           st_consid  -0.0
# 938           5_is_udal       1_full_salary   0.0
# 20           time_delta          3_is_freel  -0.0
# 407  1_is_single_moscow           st_arhive  -0.0
# 18           time_delta             3_is_ip  -0.0
# 177           task_link          2_vol_time  -0.0
# 350       1_full_salary         5_is_office  -0.0
# 0            time_delta          time_delta   NaN
# 26           time_delta            st_activ   NaN
#
#                           cor_range
# 340  Нулевая, полная, не определена
# 53   Нулевая, полная, не определена
# 683  Нулевая, полная, не определена
# 684  Нулевая, полная, не определена
# 82   Нулевая, полная, не определена
# 211  Нулевая, полная, не определена
# 307  Нулевая, полная, не определена
# 557  Нулевая, полная, не определена
# 645  Нулевая, полная, не определена
# 222  Нулевая, полная, не определена
# 318  Нулевая, полная, не определена
# 443  Нулевая, полная, не определена
# 938  Нулевая, полная, не определена
# 20   Нулевая, полная, не определена
# 407  Нулевая, полная, не определена
# 18   Нулевая, полная, не определена
# 177  Нулевая, полная, не определена
# 350  Нулевая, полная, не определена
# 0    Нулевая, полная, не определена
# 26   Нулевая, полная, не определена
#             var_1        var_2  corr                       cor_range
# 891     st_consid    st_consid   NaN  Нулевая, полная, не определена
# 924     is_closed    is_closed   NaN  Нулевая, полная, не определена
# 957     5_is_udal    5_is_udal   NaN  Нулевая, полная, не определена
# 990   5_is_office  5_is_office   NaN  Нулевая, полная, не определена
# 1023  5_is_gibrid  5_is_gibrid   NaN  Нулевая, полная, не определена

# %% [markdown]
# - Здесь представлены пары корреляций одинаковых столбцов (скрыты маской изначально)
# - Формат устройства через контракт не влияет на количество просмотров.
# - Нет влияния на самозанятость и на удаленку наличия полной вилки ЗП в вакансии.

# %% [markdown]
# ### Общий вывод по связям
# [Назад к содержанию](#section_id)

# %% [markdown]
# - Если опускать признаки, взятые с одних столбцов, то ярко выраженных связей между признаками описаний вакансий не наблюдается.
# - Рассматривая просмотры и отклики можно заметить, что самое большое значение корреляции наблюдается, когда в описании есть удаленный формат работы - 0,33 и 0,23 у просмотров и откликов соответственно.
# - Полная вилка ЗП практически нигде не имеет выраженной связи.
# - Наблюдается корреляция между указанием минимальной ЗП `salary_min` и типом занятости "Полная" `2_full_time`
# - Формат устройства через контракт не влияет на количество просмотров.
# - Работа в офисе становится малопривлекательной.
# - Стажировку не хотят оформлять официально.
# - Проектная работа возможно не подразумевает обязательное посещение офиса.
# - Неполная занятость возможно тоже не обязывает посещать регулярно офис.

# %% [markdown]
# Попробуем проверить влияние на популярность вакансий:
#   - вилки ЗП
#   - удаленки и других форматов работы
#   - наличия вакансии только в одном городе

# %% [markdown]
# ## Проверка гипотез
# [Назад к содержанию](#section_id)

# %% [markdown]
# Проверю несколько гипотез, связанных с вакансиями, закрытыми КА.
# Для начала проверю несколько общих гипотез, а затем несколько гипотез, связанных с вакансиями, закрытыми КА.

# %% [markdown]
# Функция ниже позволяет провести статистические тесты на основе показателей ассимметрии и эксцесса.
#
# Если показатель эксцесса находится в диапазоне (-2;2), а показатель ассимметрии - (-0,5;0.5), то тогда применяется T-тест, в противном случае - тест Манна-Уитни.
#
# Так же можно будет увидеть показатели средних и медианных значений в испытуемых группах, а так же процентную разницу значений в группах.

# %%
def hyps(df, col_1, col_2):
    a = df[df[col_1] ==  True][col_2]
    b = df[df[col_1] ==  False][col_2]
    
    skew_value = df[col_2].skew()
    kurtosis_value = df[col_2].kurtosis()
    mean_a = a.mean()
    mean_b = b.mean()
    median_a = a.median()
    median_b = b.median()
    alpha =  0.05  # критический уровень статистической значимости
    
    print('Значение ассиметрии -', skew_value)
    print('Значение эксцесса -', kurtosis_value)
    print()
    print('Среднее значение в выборке a:', mean_a)
    print('Среднее значение в выборке b:', mean_b)
    print('Разница средних в группах:', round((((a.mean()/b.mean())-1)*100),2), '%')
    print()
    print('Медианное значение в выборке a:', median_a)
    print('Медианное значение в выборке b:', median_b)
    print('Разница медиан в группах:', round((((a.median()/b.median())-1)*100),2), '%')
    print()
    # Выбор теста на основе значений kurtosis и skew
    if -2 <= kurtosis_value <=  2 or -0.5 <= skew_value <=  0.5:
        # Выполнение теста T
        results_st = st.ttest_ind(a, b, equal_var=False)
        print('Значение статистики: ', results_st.statistic)
        print('p-значение T-test:', results_st.pvalue)
        if results_st.pvalue < alpha:
            
            print("T-test: Отвергаем нулевую гипотезу")
        else:
            print("T-test: Не получилось отвергнуть нулевую гипотезу")
    else:
        # Выполнение теста U
        results_ma = st.mannwhitneyu(a, b)
        print('Значение статистики: ', results_ma.statistic)
        print('p-значение U-test: ', results_ma.pvalue)
        if results_ma.pvalue < alpha:
            print('U-test: Отвергаем нулевую гипотезу')
        else:
            print('U-test: Не получилось отвергнуть нулевую гипотезу')

# %% [markdown]
# Гипотезы будут поделены на две категории
# - анализирующие датасет в целом
# - анализирующие вакансии со статусом "закрытые КА"

# %% [markdown]
# ### Гипотезы общие
# [Назад к содержанию](#section_id)

# %% [markdown]
# #### Гипотеза 1

# %% [markdown]
# Рассматриваем фактор указания в вакансии одного города или нескольких. Проверяем количество просмотров

# %% [markdown]
# - Н0 - Между средними значениями количества просмотров вакансий, представленных в одном городе и вакансий, представленных в нескольких городах, статистически значимых __различий нет__.
# - Н1 - Между средними значениями количества просмотров вакансий, представленных в одном городе и вакансий, представленных в нескольких городах, статистически значимые __различия есть__.

# %%
# Количество просмотров - вакансия в одном городе и вакансия в несколкьих городах
hyps(df, '1_one_city', 'view_count')
# Out:
# Значение ассиметрии - 2.601611416928446
# Значение эксцесса - 10.019365007843952
#
# Среднее значение в выборке a: 40.67206132879046
# Среднее значение в выборке b: 35.08181818181818
# Разница средних в группах: 15.93 %
#
# Медианное значение в выборке a: 30.0
# Медианное значение в выборке b: 24.5
# Разница медиан в группах: 22.45 %
#
# Значение статистики:  69995.5
# p-значение U-test:  0.1445623899579613
# U-test: Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Hа имеющихся данных, на уровне значимости 5%, **нет оснований отвергнуть** нулевую гипотезу в пользу альтернативной.
#
# При этом числовые значения говорят о том, что:
# - среднее число просмотров на вакансии в одном городе больше чем в нескольких на 16%,
# - медиана - на 22,5%
# - Возможно влияние Москвы в категории "один город"

# %% [markdown]
# Проверяем ту же гипотезу, только изменив немного условие. Сравниваем Москву и любой другой город или даже несколько городов.

# %%
# Количество просмотров - вакансия в Москве и вакансия в любом другом городе или городах
hyps(df,'1_is_single_moscow', 'view_count')
# Out:
# Значение ассиметрии - 2.601611416928446
# Значение эксцесса - 10.019365007843952
#
# Среднее значение в выборке a: 40.829885057471266
# Среднее значение в выборке b: 38.85507246376812
# Разница средних в группах: 5.08 %
#
# Медианное значение в выборке a: 30.0
# Медианное значение в выборке b: 28.0
# Разница медиан в группах: 7.14 %
#
# Значение статистики:  190764.5
# p-значение U-test:  0.08562849548906382
# U-test: Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# - Hа имеющихся данных, на уровне значимости 5%, **нет оснований отвергнуть** нулевую гипотезу в пользу альтернативной.
# - Числовые показатели так же невелики - среднее и медиана 5 и 7% соответственно. Несущественная разница, чтобы утверждать, что вакансия в Москве гарантирует большое количество просмотров.

# %% [markdown]
# #### Гипотеза 2
# [Назад к содержанию](#section_id)

# %% [markdown]
# Гипотеза строится на утверждении, что наличие опции "Удаленка" в описании вакансии влияет на количество просмотров вакансии и количество откликов.

# %% [markdown]
# - Н0 - Между средними значениями количества просмотров вакансий, в которых представлен удаленный формат работы, статистически значимых __различий нет__.
# - Н1 - Между средними значениями количества просмотров вакансий, в которых представлен удаленный формат работы, статистически значимые __различия есть__.

# %%
# Проверка просмотров
hyps(df,'5_is_udal', 'view_count')
# Out:
# Значение ассиметрии - 2.601611416928446
# Значение эксцесса - 10.019365007843952
#
# Среднее значение в выборке a: 46.85586592178771
# Среднее значение в выборке b: 24.86375321336761
# Разница средних в группах: 88.45 %
#
# Медианное значение в выборке a: 36.0
# Медианное значение в выборке b: 19.0
# Разница медиан в группах: 89.47 %
#
# Значение статистики:  246106.5
# p-значение U-test:  3.9988675298570646e-32
# U-test: Отвергаем нулевую гипотезу

# %% [markdown]
# Теперь та же гипотеза, но с откликами.

# %% [markdown]
# - Н0 - Между средними значениями количества откликов на вакансии, в которых представлен удаленный формат работы и в которых не представлен, статистически значимых __различий нет__.
# - Н1 - Между средними значениями количества откликов на вакансии, в которых представлен удаленный формат работы и в которых не представлен, статистически значимые __различия есть__.

# %%
# Проверка откликов
hyps(df,'5_is_udal', 'resp_count')
# Out:
# Значение ассиметрии - 3.537199417256453
# Значение эксцесса - 22.339791679873613
#
# Среднее значение в выборке a: 13.135195530726257
# Среднее значение в выборке b: 7.778920308483291
# Разница средних в группах: 68.86 %
#
# Медианное значение в выборке a: 9.0
# Медианное значение в выборке b: 6.0
# Разница медиан в группах: 50.0 %
#
# Значение статистики:  223603.0
# p-значение U-test:  4.533448235725741e-16
# U-test: Отвергаем нулевую гипотезу

# %% [markdown]
# Hа имеющихся данных, на уровне значимости 5%, **есть основания отвергнуть** нулевую гипотезу в пользу альтернативной. Отвергаются обе нулевые гипотзы в пользу альтернативных.
# - Среднее значение просмотров вакансий с удаленкой на 88% выше значения просмотров вакансий без удаленки.
# - Среднее значение откликов на вакансии с удаленкой на 69% выше значения откликов на вакансии без удаленки.

# %% [markdown]
# #### Гипотеза 3
# [Назад к содержанию](#section_id)

# %% [markdown]
# Далее проверим влияние наличия полной вилки ЗП на просмотры
#
# - Н0 - Между средними значениями количества просмотров вакансий, в которых указана полная вилка ЗП и вакансий, где не указана, статистически значимых __различий нет__.
# - Н1 - Между средними значениями количества просмотров вакансий, в которых указана полная вилка ЗП и вакансий, где не указана, статистически значимые __различия есть__.

# %%
hyps(df,'1_full_salary', 'view_count')
# Out:
# Значение ассиметрии - 2.601611416928446
# Значение эксцесса - 10.019365007843952
#
# Среднее значение в выборке a: 42.082508250825086
# Среднее значение в выборке b: 39.60958205912334
# Разница средних в группах: 6.24 %
#
# Медианное значение в выборке a: 31.0
# Медианное значение в выборке b: 29.0
# Разница медиан в группах: 6.9 %
#
# Значение статистики:  154093.5
# p-значение U-test:  0.33208241725034504
# U-test: Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# - Hа имеющихся данных, на уровне значимости 5%, **нет оснований отвергнуть** нулевую гипотезу в пользу альтернативной.
# - Оба показателя разницы невелики (всего 6%).

# %% [markdown]
# ### Гипотезы по закрытым вакансиям
# [Назад к содержанию](#section_id)

# %% [markdown]
# Гипотезы 4-6 аналогичны гипотезам 1-3, за искючением того, что теперь рассматриваем данные вакансий, закрытых КА.

# %%
print('Строк в выборке:',df.query('status == "Закрыта нами"').id.count())
# Out:
# Строк в выборке: 320

# %% [markdown]
# Выборка будет небольшая

# %% [markdown]
# #### Гипотеза 4

# %% [markdown]
# Проверяем гипотезу о вакансиях в одном городе и в нескольких

# %%
hyps(df.query('status == "Закрыта нами"'), '1_one_city', 'view_count')
# Out:
# Значение ассиметрии - 2.0797832032648302
# Значение эксцесса - 6.323270115541101
#
# Среднее значение в выборке a: 49.62582781456954
# Среднее значение в выборке b: 50.666666666666664
# Разница средних в группах: -2.05 %
#
# Медианное значение в выборке a: 40.5
# Медианное значение в выборке b: 37.5
# Разница медиан в группах: 8.0 %
#
# Значение статистики:  2803.5
# p-значение U-test:  0.8235932082149655
# U-test: Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Hа имеющихся данных, на уровне значимости 5%, **нет оснований отвергнуть** нулевую гипотезу в пользу альтернативной.
# На этот раз числовые показатели разницы достаточно малы - 2% и 8% для среднего и медианы соответственно.

# %%
hyps(df.query('status == "Закрыта нами"'),'1_is_single_moscow', 'view_count')
# Out:
# Значение ассиметрии - 2.0797832032648302
# Значение эксцесса - 6.323270115541101
#
# Среднее значение в выборке a: 47.930131004366814
# Среднее значение в выборке b: 54.0989010989011
# Разница средних в группах: -11.4 %
#
# Медианное значение в выборке a: 39.0
# Медианное значение в выборке b: 42.0
# Разница медиан в группах: -7.14 %
#
# Значение статистики:  9995.5
# p-значение U-test:  0.5705250658409559
# U-test: Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# - Hа имеющихся данных, на уровне значимости 5%, **нет оснований отвергнуть** нулевую гипотезу в пользу альтернативной.
# - Разницы в группах этой выборки больше, нежели в группах общего датасета, однако наблюдается преобладание второй группы, а именно вакансий, у которых в городах не указана Москва.

# %% [markdown]
# #### Гипотеза 5
# [Назад к содержанию](#section_id)

# %% [markdown]
# Рассматриваем просмотры и отклики вакансий при условии, что в вакансии есть "Удаленка"

# %%
hyps(df.query('status == "Закрыта нами"'),'5_is_udal', 'view_count')
# Out:
# Значение ассиметрии - 2.0797832032648302
# Значение эксцесса - 6.323270115541101
#
# Среднее значение в выборке a: 54.824902723735406
# Среднее значение в выборке b: 28.714285714285715
# Разница средних в группах: 90.93 %
#
# Медианное значение в выборке a: 46.0
# Медианное значение в выборке b: 22.0
# Разница медиан в группах: 109.09 %
#
# Значение статистики:  12288.5
# p-значение U-test:  1.8762219178607206e-10
# U-test: Отвергаем нулевую гипотезу

# %%
hyps(df.query('status == "Закрыта нами"'),'5_is_udal', 'resp_count')
# Out:
# Значение ассиметрии - 2.511634131988178
# Значение эксцесса - 9.070101976171836
#
# Среднее значение в выборке a: 16.494163424124512
# Среднее значение в выборке b: 10.222222222222221
# Разница средних в группах: 61.36 %
#
# Медианное значение в выборке a: 12.0
# Медианное значение в выборке b: 9.0
# Разница медиан в группах: 33.33 %
#
# Значение статистики:  10217.5
# p-значение U-test:  0.0012551552362989012
# U-test: Отвергаем нулевую гипотезу

# %% [markdown]
# Hа имеющихся данных, на уровне значимости 5%, **есть основания отвергнуть** нулевую гипотезу в пользу альтернативной. Отвергаются обе нулевые гипотезы в пользу альтернативных.
# - При этом показатели разницы меньше, чем в общем датасете.
# - Среднее значение просмотров вакансий с удаленкой на 61% выше значения просмотров вакансий без удаленки.
# - Среднее значение откликов на вакансии с удаленкой на 33% выше значения откликов на вакансии без удаленки.

# %% [markdown]
# #### Гипотеза 6
# [Назад к содержанию](#section_id)

# %% [markdown]
# Проверяем влияние полностью указанной вилки ЗП на просмотры

# %%
hyps(df.query('status == "Закрыта нами"'), '1_full_salary', 'view_count')
# Out:
# Значение ассиметрии - 2.0797832032648302
# Значение эксцесса - 6.323270115541101
#
# Среднее значение в выборке a: 48.803030303030305
# Среднее значение в выборке b: 49.91338582677165
# Разница средних в группах: -2.22 %
#
# Медианное значение в выборке a: 34.5
# Медианное значение в выборке b: 42.5
# Разница медиан в группах: -18.82 %
#
# Значение статистики:  7725.5
# p-значение U-test:  0.32723070935292364
# U-test: Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# - Hа имеющихся данных, на уровне значимости 5%, **нет оснований отвергнуть** нулевую гипотезу в пользу альтернативной.
# - Показатели разницы незначительные в обеих группах, причем разница идет все же в пользу просмотров вакансий, где не указана точная вилка ЗП

# %% [markdown]
# Дополнительно можно посмотреть, как влияет на просмотры указание работы в офисе или гибрид.

# %% [markdown]
# За нулевую гипотезу примем, что статистически значимых различий нет, а за альтернативную - что статистически значимые различия есть

# %%
hyps(df.query('status == "Закрыта нами"'),'5_is_office', 'view_count')
# Out:
# Значение ассиметрии - 2.0797832032648302
# Значение эксцесса - 6.323270115541101
#
# Среднее значение в выборке a: 38.0
# Среднее значение в выборке b: 53.450413223140494
# Разница средних в группах: -28.91 %
#
# Медианное значение в выборке a: 24.0
# Медианное значение в выборке b: 46.0
# Разница медиан в группах: -47.83 %
#
# Значение статистики:  5978.5
# p-значение U-test:  1.1256557523315572e-06
# U-test: Отвергаем нулевую гипотезу

# %%
hyps(df.query('status == "Закрыта нами"'),'5_is_gibrid', 'view_count')
# Out:
# Значение ассиметрии - 2.0797832032648302
# Значение эксцесса - 6.323270115541101
#
# Среднее значение в выборке a: 44.60919540229885
# Среднее значение в выборке b: 51.5793991416309
# Разница средних в группах: -13.51 %
#
# Медианное значение в выборке a: 29.0
# Медианное значение в выборке b: 45.0
# Разница медиан в группах: -35.56 %
#
# Значение статистики:  7563.0
# p-значение U-test:  0.0004773957553383773
# U-test: Отвергаем нулевую гипотезу

# %% [markdown]
# Hа имеющихся данных, на уровне значимости 5%, **есть основания отвергнуть** нулевые гипотезы в пользу альтернативных.
# - При этом можно наблюдать, что значения разниц в группах в обоих случаях идут в пользу тех, где не указан тот или иной исследуемый признак. То есть традиционные формат работы уступают формату удаленки например.

# %% [markdown]
# ## Вывод по проекту
# [Назад к содержанию](#section_id)

# %% [markdown]
# Проведен анализ вакансий кадрового агенства. Целью было выявить взаимосвязи различных категорий данных в резюме, а так же выявить факторы, которые влияют на популярность вакансии.
#
# Были проведены предобработка данных, а так же кодирование новых признаков. Было принято решение раскодировать основные категориальные столбцы с целью более углубленного изучения взаимосвязей.
#
# Далее была построена матрица корреляций, результаты были оформлены в таблицу по парам значений, а так с ранжированием на категории по силе связи.
#
# Рассматривая просмотры и отклики можно заметить, что самое большое значение корреляции наблюдается, когда в описании есть удаленный формат работы - 0,33 и 0,23 у просмотров и откликов соответственно. После анализа было принято решение проверить некоторые признаки путем деления данных на выборки, а так же проверку статистическими тестами.
#
# Первые 4 гипотезы были проверены на выборках из общего датасета.
#
# **Гипотеза 1**
# - Заключалась в проверке, есть ли разница между средними значениями просмотров вакансий, представленных в одном городе и в нескольких.
#   - Выборка А - вакансия в одном городе
#   - Выборка В - вакансия в нескольких городах
#
# - Статистически значимых различий нет, что говорит о случайном распределении данных.
#   - Среднее значение в выборке a: 41
#   - Среднее значение в выборке b: 35
#   - Разница средних в группах: 15.93 %
#   - Медианное значение в выборке a: 30.0
#   - Медианное значение в выборке b: 24.5
#   - Разница медиан в группах: 22.45 %
# - Выборка А превосходит по результу выборку В
#  - среднее значение - на 16%
#  - медиана на 22.5%
#
# Гипотеза подтверждается в пользу вакансий, у которых представлен один город в описании
#
# **Гипотеза 2**
# - Гипотеза строится на утверждении, что наличие опции "Удаленка" в описании вакансии влияет на количество просмотров вакансии.
#   - Выборка А - вакансия с удаленкой в описании
#   - Выборка В - вакансия без удаленки в описании
# - Статистически значимые различия есть, что говорит о неслучайном распределении данных и требует углубленного анализа
#   - Среднее значение в выборке a: 47
#   - Среднее значение в выборке b: 25
#   - Разница средних в группах: 88.45 %
#   - Медианное значение в выборке a: 36.0
#   - Медианное значение в выборке b: 19.0
#   - Разница медиан в группах: 89.47 %
#
# Гипотеза подтверждается в пользу выборки с удаленкой. Оба показателя разницы на уровне 89-90% в пользу вакансий с удаленной работой
#
# **Гипотеза 3**
# - Гипотеза строится на утверждении, что наличие полной вилки в ЗП в описании вакансии влияет на количество просмотров вакансии.
#   - Выборка А - вакансия с указанной полностью вилкой
#   - Выборка В - вакансия без указанной полностью вилки
# - Статистически значимых различий нет, что говорит о случайном распределении данных.
#   - Среднее значение в выборке a: 42
#   - Среднее значение в выборке b: 40
#   - Разница средних в группах: 6.24 %
#   - Медианное значение в выборке a: 31.0
#   - Медианное значение в выборке b: 29.0
#   - Разница медиан в группах: 6.9 %
#
# Группа с полностью указанной вилкой преобладает на второй группой, но разница между значенями в районе 6-7%, небольшая. Говорить о существенной разнице не приходится.
#
# Следущие гипотезы были проверены на вакансиях, статус которых был "Закрыто КА"
#
# **Гипотеза 4**
# - Заключалась в проверке, есть ли разница между средними значениями просмотров вакансий, представленных в одном городе и в нескольких.
#   - Выборка А - вакансия в одном городе
#   - Выборка В - вакансия в нескольких городах
#
# - Статистически значимых различий нет, что говорит о случайном распределении данных.
#   - Среднее значение в выборке a: 50
#   - Среднее значение в выборке b: 51
#   - Разница средних в группах: -2.05 %
#   - Медианное значение в выборке a: 40.5
#   - Медианное значение в выборке b: 37.5
#   - Разница медиан в группах: 8.0 %
# - Здесь уже выборка В превосходит по результу выборку А по среднему значению - но всего на 2%
# - Выборка А превосходит по результу выборку В по медианному значению на 8%.
#
# В данном случае гипотеза подтверждает в пользу вакансий, в описании которых представлено более одного города. Если же рассматривать медиану, то тогда будут лидировать вакансии с одним городом в описании.
#
# **Гипотеза 5**
# - Гипотеза строится на утверждении, что наличие опции "Удаленка" в описании вакансии влияет на количество просмотров вакансии.
#   - Выборка А - вакансия с удаленкой в описании
#   - Выборка В - вакансия без удаленки в описании
# - Статистически значимые различия есть, что говорит о неслучайном распределении данных и требует углубленного анализа
#   - Среднее значение в выборке a: 55
#   - Среднее значение в выборке b: 29
#   - Разница средних в группах: 90.93 %
#   - Медианное значение в выборке a: 46.0
#   - Медианное значение в выборке b: 22.0
#   - Разница медиан в группах: 109.09 %
#
# В закрытых вакансиях наибольшие показатели среднего числа просмотров у вакансий с удаленкой - на 90% больше, чем вакансии без нее.
#
# **Гипотеза 6**
# - Гипотеза строится на утверждении, что наличие полной вилки в ЗП в описании вакансии влияет на количество просмотров вакансии.
#   - Выборка А - вакансия с указанной полностью вилкой
#   - Выборка В - вакансия без указанной полностью вилки
# - Статистически значимых различий нет, что говорит о случайном распределении данных.
#   - Среднее значение в выборке a: 48,9
#   - Среднее значение в выборке b: 50
#   - Разница средних в группах: -2.22 %
#   - Медианное значение в выборке a: 34.5
#   - Медианное значение в выборке b: 42.5
#   - Разница медиан в группах: -18.82 %
#
# В данном случае видно, что вакансии без уточненной вилки имеют больше просмотров.
#
# На основе результатов исследования можно выявить некоторые особенности
# - Возможность удаленной работы повышает просматриваемость. После пандемийной изоляции подобное явление справедливо.
# - Наличие вакансии в одном и городе или нескольких несущественно влияет на популярность вакансии.
# - Указанние неполной видки ЗП дает больше пространства для обсуждения зарпдатных ожиданий, а значит такие вакансии более привлекательные.
